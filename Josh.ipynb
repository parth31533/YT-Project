# %% [markdown]
# <a href="https://colab.research.google.com/github/parth31533/YT-Project/blob/main/Josh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links(channel_id):
    """Fetch all video links from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_links.append(f"https://www.youtube.com/watch?v={video_id}")

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links

def extract_transcripts(video_links, output_file="transcripts.txt"):
    """Extract transcripts for all videos and save them to a text file."""
    with open(output_file, "w", encoding="utf-8") as file:
        for link in video_links:
            video_id = link.split("v=")[-1]
            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                file.write(f"Transcript for {link}:\n")
                for line in transcript:
                    file.write(f"{line['text']}\n")
                file.write("\n" + "-" * 80 + "\n\n")
                print(f"Transcript extracted for: {link}")
            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

    print(f"\nTranscripts saved to {output_file}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID
    output_file_name = "yt_transcripts.txt"

    # Step 1: Get video links
    print("Fetching video links...")
    video_links = get_channel_video_links(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to file
        print("Extracting transcripts...")
        extract_transcripts(video_links, output_file_name)

        # Step 3: Inform the user
        print(f"Download completed. File saved as: {output_file_name}")
    else:
        print("No videos found or an error occurred.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f0bf2fd66b06> in <cell line: 2>()
#       1 from googleapiclient.discovery import build
# ----> 2 from youtube_transcript_api import YouTubeTranscriptApi
#       3 import os
#       4
#       5 # Replace with your YouTube Data API v3 key
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.8.30)
# Downloading youtube_transcript_api-0.6.3-py3-none-any.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.3

# %%
from youtube_transcript_api import YouTubeTranscriptApi
print("youtube-transcript-api installed successfully!")
# Out:
# youtube-transcript-api installed successfully!

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links(channel_id):
    """Fetch all video links from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_links.append(f"https://www.youtube.com/watch?v={video_id}")

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links

def extract_transcripts(video_links, output_file="transcripts.txt"):
    """Extract transcripts for all videos and save them to a text file."""
    with open(output_file, "w", encoding="utf-8") as file:
        for link in video_links:
            video_id = link.split("v=")[-1]
            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                file.write(f"Transcript for {link}:\n")
                for line in transcript:
                    file.write(f"{line['text']}\n")
                file.write("\n" + "-" * 80 + "\n\n")
                print(f"Transcript extracted for: {link}")
            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

    print(f"\nTranscripts saved to {output_file}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID
    output_file_name = "yt_transcripts.txt"

    # Step 1: Get video links
    print("Fetching video links...")
    video_links = get_channel_video_links(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to file
        print("Extracting transcripts...")
        extract_transcripts(video_links, output_file_name)

        # Step 3: Inform the user
        print(f"Download completed. File saved as: {output_file_name}")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript extracted for: https://www.youtube.com/watch?v=Og142I-11hw
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript extracted for: https://www.youtube.com/watch?v=O0P3FqKdUnY
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript extracted for: https://www.youtube.com/watch?v=R6z_dkHAHh4
# Transcript extracted for: https://www.youtube.com/watch?v=3mNStBOkZ2U
# Transcript extracted for: https://www.youtube.com/watch?v=qw2-GVk8z4w
# Transcript extracted for: https://www.youtube.com/watch?v=LvxFWod6n98
# Transcript extracted for: https://www.youtube.com/watch?v=Orhca1vV8Uw
# Transcript extracted for: https://www.youtube.com/watch?v=HlQKQGvLeqo
# Transcript extracted for: https://www.youtube.com/watch?v=bUo7AAoHHfA
# Transcript extracted for: https://www.youtube.com/watch?v=AQFFMveRavQ
# Transcript extracted for: https://www.youtube.com/watch?v=4ZOMrfVKS9g
# Transcript extracted for: https://www.youtube.com/watch?v=zh2PTLPfmn8
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f0bf2fd66b06> in <cell line: 66>()
#      78         # Step 2: Extract transcripts and save to file
#      79         print("Extracting transcripts...")
# ---> 80         extract_transcripts(video_links, output_file_name)
#      81
#      82         # Step 3: Inform the user
#
# <ipython-input-4-f0bf2fd66b06> in extract_transcripts(video_links, output_file)
#      53             video_id = link.split("v=")[-1]
#      54             try:
# ---> 55                 transcript = YouTubeTranscriptApi.get_transcript(video_id)
#      56                 file.write(f"Transcript for {link}:\n")
#      57                 for line in transcript:
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in get_transcript(cls, video_id, languages, proxies, cookies, preserve_formatting)
#     152         assert isinstance(video_id, str), "`video_id` must be a string"
#     153         return (
# --> 154             cls.list_transcripts(video_id, proxies, cookies)
#     155             .find_transcript(languages)
#     156             .fetch(preserve_formatting=preserve_formatting)
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in fetch(self, preserve_formatting)
#     319         :rtype [{'text': str, 'start': float, 'end': float}]:
#     320         """
# --> 321         response = self._http_client.get(
#     322             self._url, headers={"Accept-Language": "en-US"}
#     323         )
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#     791                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     544         response._pool = self  # type: ignore[attr-defined]
#     545
# --> 546         log.debug(
#     547             '%s://%s:%s "%s %s HTTP/%s" %s %s',
#     548             self.scheme,
#
# KeyboardInterrupt:

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links(channel_id):
    """Fetch all video links and titles from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for link, title in zip(video_links, video_titles):
        video_id = link.split("v=")[-1]
        sanitized_title = sanitize_filename(title)
        current_date = datetime.now().strftime("%Y-%m-%d")
        file_name = f"{sanitized_title}_{current_date}.txt"
        file_path = os.path.join(output_folder, file_name)

        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            with open(file_path, "w", encoding="utf-8") as file:
                for line in transcript:
                    file.write(f"{line['text']}\n")
            print(f"Transcript saved for: {title}")
        except Exception as e:
            print(f"Could not fetch transcript for {link}: {e}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links and titles
    print("Fetching video links and titles...")
    video_links, video_titles = get_channel_video_links(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'video_transcripts' folder.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links and titles...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: CRYPTO TO THE....BE RESPONSIBLE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: December Stocks - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Transcript saved for: Data Dump - GDP, PCE, Personal Income -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: SCOTT BESSENT IS TREASURER -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVIDIA EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JEROME POWELL LIVE @ 3PM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CRYPTO IS GOING CRAZY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JOBS REPORT REVISION - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Terrible Tuesday - Stock Market LIVE
# Transcript saved for: August Volatility - Stock Market LIVE
# Transcript saved for: Friday After Next Volatility
# Transcript saved for: PPI DATA
# Transcript saved for: THE BIG DATA WEEK
# Transcript saved for: INITIAL JOBLESS CLAIMS (People care about it now)
# Transcript saved for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for: MSFT & AMD EARNINGS
# Transcript saved for: EARNINGS, FED & END OF THE MONTH TRADING
# Transcript saved for: VOLATILITY Is HIDING - TSLA EARNINGS LIVE
# Transcript saved for: JOE BIDEN QUITS!!
# Transcript saved for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Transcript saved for: CHIP STOCK CARNAGE - NFLX EARNINGS LIVE
# Transcript saved for: SMALL CAP ROTATION
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: JEROME POWELL LIVE @ 12:30PM EST
# Transcript saved for: PPI VS. TRADERS
# Transcript saved for: CPI LIVE @ 8:30AM EST
# Transcript saved for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved for: MONDAY MELT UP
# Transcript saved for
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for: CPI LIVE @ 8:30AM EST
# Transcript saved for: THE BIGGEST WEEK FOR STOCKS
# Transcript saved for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved for: THETA THURSDAY
# Transcript saved for: ADP PRIVATE PAYROLLS
# Transcript saved for: JOLTS JOBS DATA & ISM SERVICES
# Transcript saved for: MONDAY MELT UP
# Transcript saved for: JEROME POWELL LIVE @ 11AM EST
# Transcript saved for: REAL Tesla Cyber Truck Event LIVE
# Transcript saved for: GDP DATA
# Transcript saved for: FED SPEAKERS & BOND AUCTION
# Transcript saved for: MONDAY MARKET MOVERS
# Transcript saved for: BLACK FRIDAY STOCK MARKET
# Transcript saved for: 4th Annual Stock Market THANKSGIVING
# Transcript saved for: Durable Goods & Consumer Sentiment (LOW VOLUME TRADING)
# Transcript saved for: FED MINUTES @ 2PM EST
# Transcript saved for: 20 YEAR BOND AUCTION @ 1PM EST
# Transcript saved for: Fakeout Friday
# Transcript saved for: FED SPEAKERS VS. MARKET RALLY
# Transcript saved for: PPI REPORT & RETAIL SALES
# Transcript saved for: CPI LIVE @ 8:30AM EST
# Transcript saved for: MONDAY MANIA
# Transcript saved for: The Market IS WILD
# Transcript saved for: JEROME POWELL LIVE @ 2PM EST
# Transcript saved for: JEROME POWELL LIVE PREMARKET
# Transcript saved for: The FIRST Bond Auction Of The Week
# Transcript saved for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved for: AAPL EARNINGS LIVE (The stock market is still reacting to Powell though)
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved for: Relief or Reverse
# Transcript saved for: MOODY MONDAY
# Transcript saved for: FEARFUL FRIDAY
# Transcript saved for: AMZN EARNINGS + MARKET CARNAGE
# Transcript saved for: META EARNINGS LIVE
# Transcript saved for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved for: Rates Vs. War
# Transcript saved for: FREAK OUT FRIDAY
# Transcript saved for: JEROME POWELL LIVE @ 12PM EST
# Transcript saved for: TSLA & NFLX EARNINGS + Global Conflict
# Transcript saved for: GS, BAC, JNJ, LMT EARNINGS
# Transcript saved for: EARNINGS SEASON BEGINS - Stock Market Today
# Transcript saved for: CONSUMER SENTIMENT + BOND BLOWOUT - Stock Market Today
# Transcript saved for: CPI LIVE @8:30AM EST - Stock Market Today
# Transcript saved for: FED MINUTES @ 2PM EST - Stock Market Today
# Transcript saved for: GLOBAL TENSIONS
# Transcript saved for: THE WEEK OF THE CPI
# Transcript saved for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved for: FED SPEAKERS
# Transcript saved for: ISM SERVICES @ 10AM EST
# Transcript saved for: JOLTS JOB OPENINGS @ 10AM EST
# Transcript saved for: JEROME POWELL ROUNDTABLE  LIVE @ 11AM EST
# Transcript saved for: PCE & Consumer Sentiment
# Transcript saved for: GDP Vs. OIL
# Transcript saved for: WAKE UP WEDNESDAY
# Transcript saved for: BOND BLOWOUT
# Transcript saved for: Oil & Interest Rates
# Transcript saved for: THE DOLLAR VS. THE STOCK MARKET
# Transcript saved for: POST FED DATA DUMP
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for

# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ehxjepqoOno! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: STOCKS DROP ON RECESSION FEARS
# Transcript saved for: ISM DATA RELEASE @ 10AM
# Transcript saved for: PCE INFLATION REPORT!
# Transcript saved for: JEROME POWELL LIVE & GDP
# Transcript saved for: ECONOMIC DATA @ 10AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=gcYNUgEtXJQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gcYNUgEtXJQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for: MARKET SELL OFF
# Could not fetch transcript for https://www.youtube.com/watch?v=Qi81iXg4yhE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Qi81iXg4yhE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: THE ECB SELL OFF
# Could not fetch transcript for https://www.youtube.com/watch?v=DxdZrdhbaIw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DxdZrdhbaIw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: CONSUMER CARNAGE
# Could not fetch transcript for https://www.youtube.com/watch?v=rZ8yoJ7QsX4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=rZ8yoJ7QsX4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# ...
# Transcript saved for: Tesla Model Y Unveiling LIVE – TSLA Stock
# Could not fetch transcript for https://www.youtube.com/watch?v=zf1j6djHTBs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zf1j6djHTBs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: How To Sell Premium Like A Boss – The Poor Man Spread – Option Trading For Beginners
# Could not fetch transcript for https://www.youtube.com/watch?v=BpSRcZWKDCQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BpSRcZWKDCQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=ilpJ1SAbUvk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ilpJ1SAbUvk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=mUdic3vV0Yc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mUdic3vV0Yc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=wEmysW97_Vc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wEmysW97_Vc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=s2lONzA5KWg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=s2lONzA5KWg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=SmFrT-DD85k:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=SmFrT-DD85k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=qcmmtTA2uFU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=qcmmtTA2uFU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=o3fy6f8HtcQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=o3fy6f8HtcQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=HX6xMZyG8mc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HX6xMZyG8mc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Is The Stock Market Going To Crash? – Day Trading Live, Stock Market News & Trading Options!
# Could not fetch transcript for https://www.youtube.com/watch?v=93St_G53gXk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=93St_G53gXk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=VO4Z79gT-Ms:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VO4Z79gT-Ms! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Trading Options! – POWER HOUR Fed Hearing, Brexit, & Banks
# Could not fetch transcript for https://www.youtube.com/watch?v=OeGf7IEEuvs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OeGf7IEEuvs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=9DMsehUikCI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9DMsehUikCI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=22_Qpuh4OuQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=22_Qpuh4OuQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Real Estate Investing For Beginners - Investment Properties & The Housing Marker 2019
# Could not fetch transcript for https://www.youtube.com/watch?v=upVG9TXfKgg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=upVG9TXfKgg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=BzN9O78sOfQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BzN9O78sOfQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=DCLbE59NsoU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DCLbE59NsoU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=p-8AXE35zuY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=p-8AXE35zuY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=tSYERw8HtMc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tSYERw8HtMc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Trading Options! – Robinhood App Account Challenge
# Could not fetch transcript for https://www.youtube.com/watch?v=3tX4soeZrcc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3tX4soeZrcc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Trading Options! – Markets Up On Border Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=offQRnkCLN4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=offQRnkCLN4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Stocks To Trade NOW! Market Volatility & Trade Deal
# Transcript saved for: Day Trading Live, Stock Market News & Stocks To Trade NOW! Market Volatility & Trade Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=J_pBoaXk_4U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=J_pBoaXk_4U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Download completed. Transcripts saved in the 'video_transcripts' folder.

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime
import shutil

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links(channel_id):
    """Fetch all video links and titles from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for link, title in zip(video_links, video_titles):
        video_id = link.split("v=")[-1]
        sanitized_title = sanitize_filename(title)
        current_date = datetime.now().strftime("%Y-%m-%d")
        file_name = f"{sanitized_title}_{current_date}.txt"
        file_path = os.path.join(output_folder, file_name)

        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            with open(file_path, "w", encoding="utf-8") as file:
                for line in transcript:
                    file.write(f"{line['text']}\n")
            print(f"Transcript saved for: {title}")
        except Exception as e:
            print(f"Could not fetch transcript for {link}: {e}")

def zip_transcripts_folder(folder_name="video_transcripts"):
    """Compress the transcripts folder into a zip file."""
    zip_file_name = f"{folder_name}.zip"
    shutil.make_archive(folder_name, 'zip', folder_name)
    print(f"Folder '{folder_name}' compressed into '{zip_file_name}' for download.")
    return zip_file_name

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links and titles
    print("Fetching video links and titles...")
    video_links, video_titles = get_channel_video_links(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles)

        # Step 3: Compress the folder for download
        print("Compressing transcripts folder...")
        zip_file = zip_transcripts_folder()

        # Step 4: Inform the user
        print(f"Download completed. Transcripts saved in the 'video_transcripts' folder as '{zip_file}'.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links and titles...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: CRYPTO TO THE....BE RESPONSIBLE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: December Stocks - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Transcript saved for: Data Dump - GDP, PCE, Personal Income -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: SCOTT BESSENT IS TREASURER -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVIDIA EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JEROME POWELL LIVE @ 3PM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CRYPTO IS GOING CRAZY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: JOBS REPORT REVISION - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved for: Terrible Tuesday - Stock Market LIVE
# Transcript saved for: August Volatility - Stock Market LIVE
# Transcript saved for: Friday After Next Volatility
# Transcript saved for: PPI DATA
# Transcript saved for: THE BIG DATA WEEK
# Transcript saved for: INITIAL JOBLESS CLAIMS (People care about it now)
# Transcript saved for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for: MSFT & AMD EARNINGS
# Transcript saved for: EARNINGS, FED & END OF THE MONTH TRADING
# Transcript saved for: VOLATILITY Is HIDING - TSLA EARNINGS LIVE
# Transcript saved for: JOE BIDEN QUITS!!
# Transcript saved for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Transcript saved for: CHIP STOCK CARNAGE - NFLX EARNINGS LIVE
# Transcript saved for: SMALL CAP ROTATION
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: JEROME POWELL LIVE @ 12:30PM EST
# Transcript saved for: PPI VS. TRADERS
# Transcript saved for: CPI LIVE @ 8:30AM EST
# Transcript saved for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved for: MONDAY MELT UP
# Transcript saved for: STOCK MARKET HALF DAY
# Transcript saved for: JEROME POWELL @ 9:30AM EST - JOLTS Job Openings
# Transcript saved for: First Trading Day Of July 2024 - RoaringKitty BUYS CHWY
# Transcript saved for: PCE DATA LIVE - POST DEBATE
# Transcript saved for: GDP DAY
# Transcript saved for: MICRON EARNINGS
# Transcript saved for: FEDEX EARNINGS
# Transcript saved for: MOGUL MONDAY
# Transcript saved for: S&P PMI
# Transcript saved for: GLOBAL DATA
# Transcript saved for: RETAIL SALES
# Transcript saved for: BIG MONEY MONDAY
# Transcript saved for: CONSUMER SENTIMENT
# Transcript saved for: PPI & POST POWELL
# Transcript saved for: JEROME POWELL LIVE
# Transcript saved for: BOND AUCTION & CPI PREGAME
# Transcript saved for: STOCK MARKET MONDAY
# Transcript saved for: NON FARM PAYROLLS LIVE
# Could not fetch transcript for https://www.youtube.com/watch?v=uaYX3elpATE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uaYX3elpATE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: BANK OF CANADA & PRIVATE PAYROLLS
# Transcript saved for: JOLTS JOB OPENINGS
# Transcript saved for: JOBS WEEK - $100M ON GME
# Transcript saved for: PCE DATA & FINAL FRIDAY
# Transcript saved for: GDP THURSDAY
# Transcript saved for: Wow it's already Wednesday
# Transcript saved for: SHORT WEEK, NEW HIGHS!
# Transcript saved for: NVDA STOCK IS GOING IN INSANE
# Transcript saved for: NVDA EARNINGS LIVE - FOMC MINUTES
# Transcript saved for: TOO SQUEEZY TUESDAY - MSFT EVENT
# Transcript saved for: STOCK MARKET IS INSANE
# Transcript saved for: FREAKY FRIDAY EXPIRATION
# Transcript saved for: S&P500 ALL TIME HIGHS
# Transcript saved for: CPI LIVE @ 8:30AM EST
# Transcript saved for
# Transcript saved for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved for: AAPL EARNINGS LIVE (The stock market is still reacting to Powell though)
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved for: Relief or Reverse
# Transcript saved for: MOODY MONDAY
# Transcript saved for: FEARFUL FRIDAY
# Transcript saved for: AMZN EARNINGS + MARKET CARNAGE
# Transcript saved for: META EARNINGS LIVE
# Transcript saved for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved for: Rates Vs. War
# Transcript saved for: FREAK OUT FRIDAY
# Transcript saved for: JEROME POWELL LIVE @ 12PM EST
# Transcript saved for: TSLA & NFLX EARNINGS + Global Conflict
# Transcript saved for: GS, BAC, JNJ, LMT EARNINGS
# Transcript saved for: EARNINGS SEASON BEGINS - Stock Market Today
# Transcript saved for: CONSUMER SENTIMENT + BOND BLOWOUT - Stock Market Today
# Transcript saved for: CPI LIVE @8:30AM EST - Stock Market Today
# Transcript saved for: FED MINUTES @ 2PM EST - Stock Market Today
# Transcript saved for: GLOBAL TENSIONS
# Transcript saved for: THE WEEK OF THE CPI
# Transcript saved for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved for: FED SPEAKERS
# Transcript saved for: ISM SERVICES @ 10AM EST
# Transcript saved for: JOLTS JOB OPENINGS @ 10AM EST
# Transcript saved for: JEROME POWELL ROUNDTABLE  LIVE @ 11AM EST
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0e8bb0e466ff> in <cell line: 87>()
#      98         # Step 2: Extract transcripts and save to individual files
#      99         print("Extracting transcripts...")
# --> 100         extract_transcripts(video_links, video_titles)
#     101
#     102         # Step 3: Compress the folder for download
#
# <ipython-input-6-0e8bb0e466ff> in extract_transcripts(video_links, video_titles)
#      70
#      71         try:
# ---> 72             transcript = YouTubeTranscriptApi.get_transcript(video_id)
#      73             with open(file_path, "w", encoding="utf-8") as file:
#      74                 for line in transcript:
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in get_transcript(cls, video_id, languages, proxies, cookies, preserve_formatting)
#     152         assert isinstance(video_id, str), "`video_id` must be a string"
#     153         return (
# --> 154             cls.list_transcripts(video_id, proxies, cookies)
#     155             .find_transcript(languages)
#     156             .fetch(preserve_formatting=preserve_formatting)
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in list_transcripts(cls, video_id, proxies, cookies)
#      69                 http_client.cookies = cls._load_cookies(cookies, video_id)
#      70             http_client.proxies = proxies if proxies else {}
# ---> 71             return TranscriptListFetcher(http_client).fetch(video_id)
#      72
#      73     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in fetch(self, video_id)
#      47             self._http_client,
#      48             video_id,
# ---> 49             self._extract_captions_json(self._fetch_video_html(video_id), video_id),
#      50         )
#      51
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in _fetch_video_html(self, video_id)
#      83
#      84     def _fetch_video_html(self, video_id):
# ---> 85         html = self._fetch_html(video_id)
#      86         if 'action="https://consent.youtube.com/s"' in html:
#      87             self._create_consent_cookie(html, video_id)
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in _fetch_html(self, video_id)
#      92
#      93     def _fetch_html(self, video_id):
# ---> 94         response = self._http_client.get(
#      95             WATCH_URL.format(video_id=video_id), headers={"Accept-Language": "en-US"}
#      96         )
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1055         """
#    1056         if self.chunked and self.supports_chunked_reads():
# -> 1057             yield from self.read_chunked(amt, decode_content=decode_content)
#    1058         else:
#    1059             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1204
#    1205             while True:
# -> 1206                 self._update_chunk_length()
#    1207                 if self.chunk_left == 0:
#    1208                     break
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1123         if self.chunk_left is not None:
#    1124             return None
# -> 1125         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126         line = line.split(b";", 1)[0]
#    1127         try:
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime

# Replace with your YouTube Data API v3 key
API_KEY = "YOUR_YOUTUBE_API_KEY"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]  # ISO 8601 format
            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for link, title, date in zip(video_links, video_titles, video_dates):
        video_id = link.split("v=")[-1]
        sanitized_title = sanitize_filename(title)
        release_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d")  # Format date as YYYY-MM-DD
        file_name = f"{sanitized_title}_{release_date}.txt"
        file_path = os.path.join(output_folder, file_name)

        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            with open(file_path, "w", encoding="utf-8") as file:
                for line in transcript:
                    file.write(f"{line['text']}\n")
            print(f"Transcript saved for: {title}")
        except Exception as e:
            print(f"Could not fetch transcript for {link}: {e}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'video_transcripts' folder.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links, titles, and release dates...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-7-2d82d00d9d89> in <cell line: 82>()
#      86     # Step 1: Get video links, titles, and release dates
#      87     print("Fetching video links, titles, and release dates...")
# ---> 88     video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)
#      89
#      90     if video_links:
#
# <ipython-input-7-2d82d00d9d89> in get_channel_video_links_and_dates(channel_id)
#      22         id=channel_id
#      23     )
# ---> 24     response = request.execute()
#      25
#      26     if not response["items"]:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCsfp0zw1hNxpy_wDig8oExA&key=YOUR_YOUTUBE_API_KEY&alt=json returned "API key not valid. Please pass a valid API key.". Details: "[{'message': 'API key not valid. Please pass a valid API key.', 'domain': 'global', 'reason': 'badRequest'}]">

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]

            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for link, title, date in zip(video_links, video_titles, video_dates):
        video_id = link.split("v=")[-1]
        sanitized_title = sanitize_filename(title)
        video_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d")
        file_name = f"{sanitized_title}_{video_date}.txt"
        file_path = os.path.join(output_folder, file_name)

        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            with open(file_path, "w", encoding="utf-8") as file:
                for line in transcript:
                    file.write(f"{line['text']}\n")
            print(f"Transcript saved for: {title}")
        except Exception as e:
            print(f"Could not fetch transcript for {link}: {e}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'video_transcripts' folder.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Streaming output truncated to the last 5000 lines.
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=OpM3OxaMpjY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OpM3OxaMpjY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=I5dPeVUtCzY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=I5dPeVUtCzY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: FINAL WEDNESDAY of 2022
# Transcript saved for: THE FINAL TUESDAY OF THE YEAR!!
# Transcript saved for: PCE @ 8:30AM EST
# Transcript saved for: JOBLESS CLAIMS @ 8:30AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=TzzXiIS4xnY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TzzXiIS4xnY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: BANK OF JAPAN SHOCKS THE WORLD
# Could not fetch transcript for https://www.youtube.com/watch?v=XK_YXlahLYU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XK_YXlahLYU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=aLs2Fp7MOXc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=aLs2Fp7MOXc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=CpuNJUSvKgc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CpuNJUSvKgc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved for: $20K in 10 days. Tomorrow will be crazier…
# Transcript saved for: CPI LIVE @ 8:30 AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v
! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=DCLbE59NsoU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DCLbE59NsoU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=p-8AXE35zuY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=p-8AXE35zuY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=tSYERw8HtMc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tSYERw8HtMc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=6hGMpAqA9N0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6hGMpAqA9N0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=3tX4soeZrcc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3tX4soeZrcc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Trading Options! – Markets Up On Border Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=offQRnkCLN4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=offQRnkCLN4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=49MbC-OI3_Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=49MbC-OI3_Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved for: Day Trading Live, Stock Market News & Stocks To Trade NOW! Market Volatility & Trade Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=J_pBoaXk_4U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=J_pBoaXk_4U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Download completed. Transcripts saved in the 'video_transcripts' folder.

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime
import zipfile

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]

            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist
    zip_filename = "video_transcripts.zip"

    # Create a zip file to hold the text files
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for link, title, date in zip(video_links, video_titles, video_dates):
            video_id = link.split("v=")[-1]
            sanitized_title = sanitize_filename(title)
            video_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d")
            file_name = f"{sanitized_title}_{video_date}.txt"
            file_path = os.path.join(output_folder, file_name)

            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                with open(file_path, "w", encoding="utf-8") as file:
                    for line in transcript:
                        file.write(f"{line['text']}\n")

                # Add the transcript text file to the zip archive
                zipf.write(file_path, os.path.basename(file_path))
                print(f"Transcript saved and added to zip for: {title}")

                # Clean up by removing the file after adding it to the zip
                os.remove(file_path)
            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

    print(f"All transcripts are saved in the zip file: {zip_filename}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'video_transcripts.zip'.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links, titles, and release dates...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=O0P3FqKdUnY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=O0P3FqKdUnY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=3mNStBOkZ2U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3mNStBOkZ2U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Could not fetch transcript for https://www.youtube.com/watch?v=LvxFWod6n98:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LvxFWod6n98! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=bUo7AAoHHfA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bUo7AAoHHfA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=zh2PTLPfmn8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zh2PTLPfmn8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=4L8e73UvM0o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4L8e73UvM0o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=ur0wJJUWQtU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ur0wJJUWQtU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved and added to zip for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=nT5Fre94kG4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nT5Fre94kG4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=Qr3mUZsKNAk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Qr3mUZsKNAk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=bM3rXtOT_8c:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bM3rXtOT_8c! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=IbHDY_fSkOU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=IbHDY_fSkOU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=Ttf5Jo28iAs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Ttf5Jo28iAs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=PcCBqfw3cPI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PcCBqfw3cPI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=oqDTNCGCvH0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=oqDTNCGCvH0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved and added to zip for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Could not fetch transcript for https://www.youtube.com/watch?v=1fb6I5zm2h4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1fb6I5zm2h4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=iZYS1f9hoTY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iZYS1f9hoTY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: EARNINGS, FED & END OF THE MONTH TRADING
# Could not fetch transcript for https://www.youtube.com/watch?v=uaz7s7KKDNw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uaz7s7KKDNw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=iqxI9k6xm7o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iqxI9k6xm7o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Could not fetch transcript for https://www.youtube.com/watch?v=oqnoMmw3yTY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=oqnoMmw3yTY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=wNvdShXOUbY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wNvdShXOUbY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=O-EoaHEui0k:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=O-EoaHEui0k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=-pbXijimrW0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-pbXijimrW0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=R71dvaEWZb4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=R71dvaEWZb4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=DdNEj1WLByE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DdNEj1WLByE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=ubuEKMFIysA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ubuEKMFIysA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=8Tv-vGMhmq8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8Tv-vGMhmq8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL @ 9:30AM EST - JOLTS Job Openings
# Could not fetch transcript for https://www.youtube.com/watch?v=Yeg9-_zUXyw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Yeg9-_zUXyw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: PCE DATA LIVE - POST DEBATE
# Could not fetch transcript for https://www.youtube.com/watch?v=n9hsxWEhkD0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n9hsxWEhkD0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=g50NZ4LxdpI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=g50NZ4LxdpI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v
! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=c1oE3lciSNc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=c1oE3lciSNc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=9zrcMOSfylg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9zrcMOSfylg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=wenU7FVI7aE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wenU7FVI7aE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=fHZrryiC_wM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fHZrryiC_wM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=zQp2Sgit7zo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zQp2Sgit7zo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: FINAL TRADING DAY OF THE MONTH
# Transcript saved and added to zip for: REBALANCE THURSDAY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-94946435a6ca> in <cell line: 95>()
#     106         # Step 2: Extract transcripts and save to individual files
#     107         print("Extracting transcripts...")
# --> 108         extract_transcripts(video_links, video_titles, video_dates)
#     109
#     110         # Step 3: Inform the user
#
# <ipython-input-9-94946435a6ca> in extract_transcripts(video_links, video_titles, video_dates)
#      77
#      78             try:
# ---> 79                 transcript = YouTubeTranscriptApi.get_transcript(video_id)
#      80                 with open(file_path, "w", encoding="utf-8") as file:
#      81                     for line in transcript:
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_api.py in get_transcript(cls, video_id, languages, proxies, cookies, preserve_formatting)
#     152         assert isinstance(video_id, str), "`video_id` must be a string"
#     153         return (
# --> 154             cls.list_transcripts(video_id, proxies, cookies)
#     155             .find_transcript(languages)
#     156             .fetch(preserve_formatting=preserve_formatting)
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in fetch(self, preserve_formatting)
#     322             self._url, headers={"Accept-Language": "en-US"}
#     323         )
# --> 324         return _TranscriptParser(preserve_formatting=preserve_formatting).parse(
#     325             _raise_http_errors(response, self.video_id).text,
#     326         )
#
# /usr/local/lib/python3.10/dist-packages/youtube_transcript_api/_transcripts.py in parse(self, plain_data)
#     390                 "duration": float(xml_element.attrib.get("dur", "0.0")),
#     391             }
# --> 392             for xml_element in ElementTree.fromstring(plain_data)
#     393             if xml_element.text is not None
#     394         ]
#
# /usr/local/lib/python3.10/dist-packages/defusedxml/common.py in fromstring(text, forbid_dtd, forbid_entities, forbid_external)
#     124             forbid_external=forbid_external,
#     125         )
# --> 126         parser.feed(text)
#     127         return parser.close()
#     128
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in feed(self, data)
#    1711         """Feed encoded data to parser."""
#    1712         try:
# -> 1713             self.parser.Parse(data, False)
#    1714         except self._error as v:
#    1715             self._raiseerror(v)
#
# ../Modules/pyexpat.c in EndElement()
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in _end(self, tag)
#    1651         return self.target.start(tag, attrib)
#    1652
# -> 1653     def _end(self, tag):
#    1654         return self.target.end(self._fixname(tag))
#    1655
#
# KeyboardInterrupt:

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime
import zipfile

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]

            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist
    zip_filename = "Josh_Transcripts.zip"

    # Create a zip file to hold the text files
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        processed_video_ids = set()  # Set to track processed video IDs
        total_transcribed = 0  # Count of successfully transcribed videos
        total_videos = len(video_links)  # Total number of videos

        for link, title, date in zip(video_links, video_titles, video_dates):
            video_id = link.split("v=")[-1]

            # Skip processing if the video has already been processed
            if video_id in processed_video_ids:
                print(f"Skipping duplicate video: {title}")
                continue

            # Add the video ID to the processed set to avoid duplicates
            processed_video_ids.add(video_id)

            sanitized_title = sanitize_filename(title)
            video_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d")
            file_name = f"{sanitized_title}_{video_date}.txt"
            file_path = os.path.join(output_folder, file_name)

            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                with open(file_path, "w", encoding="utf-8") as file:
                    for line in transcript:
                        file.write(f"{line['text']}\n")

                # Add the transcript text file to the zip archive
                zipf.write(file_path, os.path.basename(file_path))
                print(f"Transcript saved and added to zip for: {title}")

                # Clean up by removing the file after adding it to the zip
                os.remove(file_path)
                total_transcribed += 1  # Increment the transcribed count
            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

        # Print out the results
        print(f"\n{total_transcribed} out of {total_videos} videos were successfully transcribed.")
        print(f"All transcripts are saved in the zip file: {zip_filename}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'Josh_Transcripts.zip'.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links, titles, and release dates...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CRYPTO TO THE....BE RESPONSIBLE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: December Stocks - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Transcript saved and added to zip for: Data Dump - GDP, PCE, Personal Income -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: SCOTT BESSENT IS TREASURER -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 3PM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CRYPTO IS GOING CRAZY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved and added to zip for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JOBS REPORT REVISION - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Terrible Tuesday - Stock Market LIVE
# Transcript saved and added to zip for: August Volatility - Stock Market LIVE
# Transcript saved and added to zip for: Friday After Next Volatility
# Transcript saved and added to zip for: PPI DATA
# Transcript saved and added to zip for: THE BIG DATA WEEK
# Transcript saved and added to zip for: INITIAL JOBLESS CLAIMS (People care about it now)
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved and added to zip for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: MSFT & AMD EARNINGS
# Transcript saved and added to zip for: EARNINGS, FED & END OF THE MONTH TRADING
# Transcript saved and added to zip for: VOLATILITY Is HIDING - TSLA EARNINGS LIVE
# Transcript saved and added to zip for: JOE BIDEN QUITS!!
# Transcript saved and added to zip for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Transcript saved and added to zip for: CHIP STOCK CARNAGE - NFLX EARNINGS LIVE
# Transcript saved and added to zip for: SMALL CAP ROTATION
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12:30PM EST
# Transcript saved and added to zip for: PPI VS. TRADERS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: STOCK MARKET HALF DAY
# Transcript saved and added to zip for: JEROME POWELL @ 9:30AM EST - JOLTS Job Openings
# Transcript saved and added to zip for: First Trading Day Of July 2024 - RoaringKitty BUYS CHWY
# Transcript saved and added to zip for: PCE DATA LIVE - POST DEBATE
# Transcript saved and added to zip for: GDP DAY
# Transcript saved and added to zip for: MICRON EARNINGS
# Transcript saved and added to zip for: FEDEX EARNINGS
# Transcript saved and added to zip for: MOGUL MONDAY
# Transcript saved and added to zip for: S&P PMI
# Transcript saved and added to zip for: GLOBAL DATA
# Transcript saved and added to zip for: RETAIL SALES
# Transcript saved and added to zip for: BIG MONEY MONDAY
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: PPI & POST POWELL
# Transcript saved and added to zip for: JEROME POWELL LIVE
# Transcript saved and added to zip for: BOND AUCTION & CPI PREGAME
# Transcript saved and added to zip for: STOCK MARKET MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE
# Could not fetch transcript for https://www.youtube.com/watch?v=uaYX3elpATE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uaYX3elpATE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: BANK OF CANADA & PRIVATE PAYROLLS
# Transcript saved and added to zip for: JOLTS JOB OPENINGS
# Transcript saved and added to zip for: JOBS WEEK - $100M ON GME
# Transcript saved and added to zip for: PCE DATA & FINAL FRIDAY
# Transcript saved and added to zip for: GDP THURSDAY
# Transcript saved and added to zip for: Wow it's already Wednesday
# Transcript saved and added to zip for: SHORT WEEK, NEW HIGHS!
# Transcript saved and added to zip for: NVDA STOCK IS GOING IN INSANE
# Transcript saved and added to zip for: NVDA EARNINGS LIVE - FOMC MINUTES
# Transcript saved and added to zip for: TOO SQUEEZY TUESDAY - MSFT EVENT
# Transcript saved and added to zip for: STOCK MARKET IS INSANE
# Transcript saved and added to zip for: FREAKY FRIDAY EXPIRATION
# Transcript saved and added to zip for: S&P500 ALL TIME HIGHS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: PPI LIVE @ 8:30AM EST - GME PART 2 - JEROME POWELL LIVE
# Transcript saved and added to zip for: THE STOCK MARKET IS BACK!! - GME - OPENAI EVENT
# Transcript saved and added to zip for: FACEOFF FRIDAY
# Transcript saved and added to zip for: THETA THURSDAY STOCK MARKET
# Transcript saved and added to zip for: 10Y AUCTION & EARNINGS
# Transcript saved and added to zip for: DISNEY EARNINGS!!! - AAPL EVENT LIVE
# Transcript saved and added to zip for: THEY NOT LIKE US MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30 AM EST
# Transcript saved and added to zip for: FOMC & JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: EMPLOYMENT COST INDEX & AMZN EARNINGS
# Transcript saved and added to zip for: ANYTHING BUT BONDS
# Transcript saved and added to zip for: PCE DATA @ 8:30 AM EST
# Transcript saved and added to zip for: GOOGL & MSFT EARNINGS LIVE - GDP DATA
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: PMI's & EARNINGS SEASON
# Transcript saved and added to zip for: $100B MARKET CAP
# Transcript saved and added to zip for: WAR TENSIONS ARE BACK
# Transcript saved and added to zip for: TSM & NFLX EARNINGS
# Transcript saved and added to zip for: INTEREST RATE RECKONING
# Transcript saved and added to zip for: GLOBAL TENSIONS & GLOBAL DATA - Jerome Powell LIVE @ 1:15PM EST
# Transcript saved and added to zip for: RETAIL SALES, MANUFACTURING & TAX DAY
# Transcript saved and added to zip for: BANK EARNINGS BEGIN!!! JPM, C, WFC
# Transcript saved and added to zip for: PPI & ECB
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST
# Transcript saved and added to zip for: GOLD IS GOING CRAZY
# Could not fetch transcript for https://www.youtube.com/watch?v=jtKbUVI5a1w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jtKbUVI5a1w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=yH717RplckU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yH717RplckU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THETA THURSDAY
# Could not fetch transcript for https://www.youtube.com/watch?v=dmI7Djtv3NY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dmI7Djtv3NY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JOLTS Job Openings
# Transcript saved and added to zip for: THE NEXT QUARTER HAS BEGUN!!!
# Transcript saved and added to zip for: LAST TRADING DAY OF THE WEEK
# Transcript saved and added to zip for: Wandering Wednesday
# Transcript saved and added to zip for: Data Dump Tuesday
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: RDDT IPO
# Transcript saved and added to zip for: Jerome Powell Live @ 2:30PM EST - FOMC Dot Plot
# Transcript saved and added to zip for: JAPAN RAISES RATES FOR THE FIRST TIME!!!
# Transcript saved and added to zip for: Bank Of Japan Pregame
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Could not fetch transcript for https://www.youtube.com/watch?v=UlwwQkPoFEE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UlwwQkPoFEE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=MnDj0KtB-Vc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=MnDj0KtB-Vc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: Daylight LONGTERMS
# Could not fetch transcript for https://www.youtube.com/watch?v=Gzn2T8P-gII:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Gzn2T8P-gII! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL LIVE DAY 2
# Transcript saved and added to zip for: JOLTS JOB OPENINGS & JEROME POWELL LIVE
# Transcript saved and added to zip for: ISM SERVICES & CHIP STOCK MANIA
# Transcript saved and added to zip for: BEWARE THE IDES OF MARCH
# Transcript saved and added to zip for: THE FIRST TRADING DAY OF MARCH!!
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP @ 8:30 AM EST
# Transcript saved and added to zip for: Durable Goods & Consumer Confidence
# Transcript saved and added to zip for: MOMENTUM MONDAY
# Transcript saved and added to zip for: MARKET SENTIMENT FRIDAY
# Could not fetch transcript for https://www.youtube.com/watch?v=NeUsNAcgF7Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NeUsNAcgF7Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: NVDA EARNINGS LIVE AH
# Transcript saved and added to zip for: WMT & HD EARNINGS
# Could not fetch transcript for https://www.youtube.com/watch?v=AhgU7Pku_4E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AhgU7Pku_4E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: The Battle of 5000 SPX
# Could not fetch transcript for https://www.youtube.com/watch?v=fbl-_xtyC9g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fbl-_xtyC9g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED SPEAKERS & CPI WEEK
# Transcript saved and added to zip for: CPI REVISIONS @ 8:30AM EST
# Transcript saved and added to zip for: THE DAY BEFORE THE REVISIONS
# Transcript saved and added to zip for: 10YR BOND AUCTION & BANK STOCK BLUNDER
# Transcript saved and added to zip for: Fed Speakers day 2
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: T'was The Day After Powell - AAPL, AMZN & META EARNINGS LIVE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: JOLTS JOBS & MSFT EARNINGS LIVE
# Transcript saved and added to zip for: STOCK EARNINGS EVERYWHERE!!!!
# Transcript saved and added to zip for: INTC EARNINGS LIVE
# Transcript saved and added to zip for: TSLA EARNINGS LIVE AH
# Transcript saved and added to zip for: TOP TICK TUESDAY
# Transcript saved and added to zip for: Rate Cuts vs. Earnings
# Transcript saved and added to zip for: THE OPTION EXPIRATION SCAM
# Transcript saved and added to zip for: THE BOSTIC BOUNCE
# Transcript saved and added to zip for: RETAIL SALES @ 8:30AM EST
# Transcript saved and added to zip for: STOCK MARKET WEEK 3 - BANK EARINGS & DATA
# Transcript saved and added to zip for: PPI @ 8:30AM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: 10YR BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Stock Market MOMENTUM
# Transcript saved and added to zip for: BA STOCK FIASCO
# Transcript saved and added to zip for: PMI SERVICES
# Transcript saved and added to zip for: FED MINUTES & JOLTS JOB REPORT
# Transcript saved and added to zip for: THE OPENING TRADE OF THE YEAR
# Transcript saved and added to zip for: NIIIIIIIIIIKEEEEESSSSSS - Stock Market IS GOING CRAZY
# Transcript saved and added to zip for: GDP DATA & MARKET SPOOKED
# Transcript saved and added to zip for: BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Bank Of Powell
# Transcript saved and added to zip for: CYCLICAL MONDAYS
# Transcript saved and added to zip for: PMI DATA & STOCK MARKET HIGHS!!!!
# Transcript saved and added to zip for: ECB, Bank Of England & RETAIL SALES - STOCK MARKET AT HIGHS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE BIGGEST WEEK FOR STOCKS
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: THETA THURSDAY
# Transcript saved and added to zip for: ADP PRIVATE PAYROLLS
# Transcript saved and added to zip for: JOLTS JOBS DATA & ISM SERVICES
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 11AM EST
# Transcript saved and added to zip for: REAL Tesla Cyber Truck Event LIVE
# Transcript saved and added to zip for: GDP DATA
# Transcript saved and added to zip for: FED SPEAKERS & BOND AUCTION
# Transcript saved and added to zip for: MONDAY MARKET MOVERS
# Transcript saved and added to zip for: BLACK FRIDAY STOCK MARKET
# Transcript saved and added to zip for: 4th Annual Stock Market THANKSGIVING
# Transcript saved and added to zip for: Durable Goods & Consumer Sentiment (LOW VOLUME TRADING)
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: 20 YEAR BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Fakeout Friday
# Transcript saved and added to zip for: FED SPEAKERS VS. MARKET RALLY
# Transcript saved and added to zip for: PPI REPORT & RETAIL SALES
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: The Market IS WILD
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2PM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE PREMARKET
# Transcript saved and added to zip for: The FIRST Bond Auction Of The Week
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AAPL EARNINGS LIVE (The stock market is still reacting to Powell though)
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved and added to zip for: Relief or Reverse
# Transcript saved and added to zip for: MOODY MONDAY
# Transcript saved and added to zip for: FEARFUL FRIDAY
# Transcript saved and added to zip for: AMZN EARNINGS + MARKET CARNAGE
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: Rates Vs. War
# Transcript saved and added to zip for: FREAK OUT FRIDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12PM EST
# Transcript saved and added to zip for: TSLA & NFLX EARNINGS + Global Conflict
# Transcript saved and added to zip for: GS, BAC, JNJ, LMT EARNINGS
# Transcript saved and added to zip for: EARNINGS SEASON BEGINS - Stock Market Today
# Transcript saved and added to zip for: CONSUMER SENTIMENT + BOND BLOWOUT - Stock Market Today
# Transcript saved and added to zip for: CPI LIVE @8:30AM EST - Stock Market Today
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST - Stock Market Today
# Transcript saved and added to zip for: GLOBAL TENSIONS
# Transcript saved and added to zip for: THE WEEK OF THE CPI
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED SPEAKERS
# Transcript saved and added to zip for: ISM SERVICES @ 10AM EST
# Transcript saved and added to zip for: JOLTS JOB OPENINGS @ 10AM EST
# Transcript saved and added to zip for: JEROME POWELL ROUNDTABLE  LIVE @ 11AM EST
# Transcript saved and added to zip for: PCE & Consumer Sentiment
# Transcript saved and added to zip for: GDP Vs. OIL
# Transcript saved and added to zip for: WAKE UP WEDNESDAY
# Transcript saved and added to zip for: BOND BLOWOUT
# Transcript saved and added to zip for: Oil & Interest Rates
# Transcript saved and added to zip for: THE DOLLAR VS. THE STOCK MARKET
# Transcript saved and added to zip for: POST FED DATA DUMP
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: MONEY - INSTACART IPO LIVE
# Transcript saved and added to zip for: POST EXPIRATION SETUP
# Transcript saved and added to zip for: UAW GOES ON STRIKE
# Transcript saved and added to zip for: ARM IPO LIVE!
# Transcript saved and added to zip for: AUGUST CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: EUROPE IS MOVING MARKETS - AAPL NEW IPHONE
# Transcript saved and added to zip for: TESTING SEE YOU IN THE MORNING
# Transcript saved and added to zip for: MACRO MONDAY
# Transcript saved and added to zip for: The Stock Market HATES September
# Transcript saved and added to zip for: STOCK MARKET LIVE - THETA THURSDAY
# Transcript saved and added to zip for: ISM SERVICES
# Transcript saved and added to zip for: SEPTEMBER SEASONALITY
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: BULLS VS. BONDS
# Transcript saved and added to zip for: JOLTS JOB OPENINGS
# Transcript saved and added to zip for: The Day After POWELL
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST - Jackson Hole Symposium
# Transcript saved and added to zip for: AI STOCK BUBBLE
# Transcript saved and added to zip for: NVDA EARNINGS LIVE
# Transcript saved and added to zip for: Curve Steepener - LIVE TRADING
# Transcript saved and added to zip for: THE BIG OPTION EXPIRATION - LIVE TRADING
# Transcript saved and added to zip for: POWELL & NVDA - LIVE TRADING
# Transcript saved and added to zip for: GLOBAL BOND BLOWOUT - LIVE TRADING
# Transcript saved and added to zip for: FED MINUTES - LIVE TRADING
# Transcript saved and added to zip for: RETAIL SALES - LIVE TRADING
# Transcript saved and added to zip for: CHINA CONTAGION  - LIVE TRADING
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - LIVE TRADING
# Transcript saved and added to zip for: WILD WEDNESDAY - LIVE TRADING
# Transcript saved and added to zip for: TIMID TUESDAY - LIVE TRADING
# Transcript saved and added to zip for: MOODY MONDAY - LIVE TRADING
# Transcript saved and added to zip for: AMZN & AAPL EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: FITCH DOWNGRADES THE USA - LIVE TRADING
# Transcript saved and added to zip for: AMD EARNINGS AFTER HOURS - LIVE TRADING
# Transcript saved and added to zip for: LAST DAY OF JULY - LIVE TRADING
# Transcript saved and added to zip for: ECB & EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - LIVE TRADING
# Transcript saved and added to zip for: GOOGL & MSFT EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: MONDAY MANIA - LIVE TRADING
# Transcript saved and added to zip for: FOLLOW THROUGH FRIDAY - LIVE TRADING
# Transcript saved and added to zip for: TSM & JNJ  EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: NFLX & TSLA EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: BANK EARNINGS EVERYWHERE - LIVE TRADING
# Transcript saved and added to zip for: EMPIRE MANUFACTURING DATA - LIVE TRADING
# Transcript saved and added to zip for: BANK STOCK EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: Producer Price Inflation & EARNINGS  - LIVE TRADING
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - LIVE TRADING
# Transcript saved and added to zip for: EARNINGS SEASON PREGAME - LIVE TRADING
# Transcript saved and added to zip for: FED SPEAKER MONDAY - LIVE TRADING
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST  - LIVE TRADING
# Transcript saved and added to zip for: ISM SERVICES, YELLEN IN CHINA, META THREADS  - LIVE TRADING
# Transcript saved and added to zip for: HALF DAY FREEDOM DAY
# Transcript saved and added to zip for: FINAL TRADING DAY OF THE MONTH
# Transcript saved and added to zip for: REBALANCE THURSDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 9:30AM EST
# Transcript saved and added to zip for: TUESDAY ECONOMIC DATA DUMP
# Transcript saved and added to zip for: Time to Hedge?
# Transcript saved and added to zip for: FROTHY FRIDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE DAY 2
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: FED SPEAKERS ALL WEEK
# Transcript saved and added to zip for: FED BULLARD & FED WALLER
# Transcript saved and added to zip for: THEY REALLY PAUSED!!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE BIGGEST TRADING WEEK
# Transcript saved and added to zip for: FORGET IT FRIDAY
# Transcript saved and added to zip for: TOP TICK THURSDAY
# Transcript saved and added to zip for: WONDERING WEDNESDAY
# Transcript saved and added to zip for: TURBULENT TUESDAY
# Transcript saved and added to zip for: PMI & ISM DATA
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: DEBT LIMIT WINS HOUSE PASSAGE
# Transcript saved and added to zip for: JOB OPENINGS & FED SPEAKERS
# Transcript saved and added to zip for: DEBT CEILING DEAL!!
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST - DEBT CEILING SHOWDOWN
# Transcript saved and added to zip for: UNITED STATES ON CREDIT WATCH
# Transcript saved and added to zip for: Fed Minutes @ 2PM EST
# Transcript saved and added to zip for: Jerome Powell Live @ New Democratic Coalition Lunch
# Transcript saved and added to zip for: FED SPEAKERS & Debt Ceiling
# Transcript saved and added to zip for: POWELL LIVE @ 11AM EST
# Transcript saved and added to zip for: BABA & WMT EARNINGS
# Transcript saved and added to zip for: Wait For Powell Wednesday
# Transcript saved and added to zip for: TUESDAY DATA DUMP
# Transcript saved and added to zip for: FED SPEAKER DAY
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'CONSUMER SENTIMENT @ 10AM EST_2023-05-12.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# Transcript saved and added to zip for: PPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: DEBT CEILING DEBATE
# Transcript saved and added to zip for: MORE NEWS MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AAPL EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved and added to zip for: AMD EARNINGS LIVE AH
# Transcript saved and added to zip for: FIRST REPUBLIC BANK IS DONE
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AMZN EARNINGS LIVE
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: FRC EARNINGS AH
# Transcript saved and added to zip for: STOCK MARKET SENTIMENT SOURS
# Transcript saved and added to zip for: TSM, AXP & REGIONAL BANK EARNINGS
# Transcript saved and added to zip for: TESLA CONFERENCE CALL LIVE
# Transcript saved and added to zip for: TSLA EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: NFLX Q1 EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: REGIONAL BANK EARNINGS
# Transcript saved and added to zip for: AIRLINE EARNINGS
# Transcript saved and added to zip for: PPI & AIRLINE EARNINGS!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: CPI PREVIEW
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING TO GO CRAZY THIS WEEK!!
# Transcript saved and added to zip for: THETA THURSDAY!!
# Transcript saved and added to zip for: WHATS REALLY GOING ON WEDNESDAY!?
# Transcript saved and added to zip for: OIL MARKET MALARKEY
# Transcript saved and added to zip for: OPEC SURPRISE CUT
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: NASDAQ BULL MARKET
# Transcript saved and added to zip for: MARKET GAP UP!!
# Transcript saved and added to zip for: FED, FDIC & TREASURY HOUSE TESTIMONY LIVE
# Transcript saved and added to zip for: MONDAY MELTUP?
# Transcript saved and added to zip for: FAKE OUT FRIDAY
# Transcript saved and added to zip for: POST POWELL CARNAGE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: Banks Vs. Powell
# Transcript saved and added to zip for: CREDIT SUISSE BUYOUT
# Transcript saved and added to zip for: FRIDAY BANK WATCH
# Transcript saved and added to zip for: FRC IS BEING RESCUED
# Transcript saved and added to zip for: EURO BANK RUN
# Transcript saved and added to zip for: EURO BANKING CRISIS PT.2
# Transcript saved and added to zip for: EURO BANK CRISIS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED INTERVENTION - SBV & SBNY FAILURE
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: TOP TICK THURSDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE  @ 10AM EST - HOUSE FINANCIAL SERVICES
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: MONDAY MELT
# Transcript saved and added to zip for: FRIDAY FINALE
# Transcript saved and added to zip for: THE STOCK MARKET IS INSANE
# Transcript saved and added to zip for: WELCOME TO MARCH!!!
# Transcript saved and added to zip for: [Insert witty title] TUESDAY
# Transcript saved and added to zip for: MAKE IT OR BREAK IT MONDAY
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP DATA LIVE!
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: TURN-AROUND TUESDAY
# Transcript saved and added to zip for: FRIDAY FIASCO!!!
# Transcript saved and added to zip for: PPI DATA @ 8:30AM EST
# Transcript saved and added to zip for: RETAIL SALES
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE CPI SETUP
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: JOBLESS CLAIMS & PYPL EARNINGS
# Transcript saved and added to zip for: DIS EARNINGS LIVE!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12:40PM EST
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: NON FARM PAYROLLS!!!
# Transcript saved and added to zip for: AAPL, AMZN & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: SNAP & AMD EARNINGS LIVE
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP & JOBLESS CLAIMS LIVE!
# Transcript saved and added to zip for: TSLA EARNINGS LIVE!!
# Transcript saved and added to zip for: MSFT EARNINGS LIVE!!
# Transcript saved and added to zip for: EARNINGS SEASON
# Transcript saved and added to zip for: NFLX EARNINGS LIVE!
# Transcript saved and added to zip for: PPI @ 5:30AM EST
# Transcript saved and added to zip for: THE GENERATIONAL RALLY
# Transcript saved and added to zip for: BANK EARNINGS BEGIN!!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: INFLATION BREAKDOWN
# Transcript saved and added to zip for: JEROME POWELL LIVE!
# Transcript saved and added to zip for: EARNINGS, POWELL & CPI!
# Transcript saved and added to zip for: 🚨NON FARM PAYROLLS @ 8:30AM EST🚨
# Transcript saved and added to zip for: JOBLESS CLAIMS & PMI
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: 1st Trading Day of The YEAR
# Transcript saved and added to zip for: THE FINAL TRADING DAY OF THE YEAR 2022
# Transcript saved and added to zip for: TIPPING POINT THURSDAY
# Transcript saved and added to zip for: FINAL WEDNESDAY of 2022
# Transcript saved and added to zip for: THE FINAL TUESDAY OF THE YEAR!!
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: JOBLESS CLAIMS @ 8:30AM EST
# Transcript saved and added to zip for: BOJ DAY 2
# Transcript saved and added to zip for: BANK OF JAPAN SHOCKS THE WORLD
# Transcript saved and added to zip for: HOMEBUILDER DATA @ 10AM EST
# Transcript saved and added to zip for: $3.7 TRILLION EXPIRATION
# Transcript saved and added to zip for: JOBLESS CLAIMS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: $20K in 10 days. Tomorrow will be crazier…
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST
# Transcript saved and added to zip for: MARKET MELT
# Transcript saved and added to zip for: PRODUCER PRICE INDEX & CONSUMER SENTIMENT!
# Transcript saved and added to zip for: JOBLESS CLAIMS @ 8:30 AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=VI8MgCzXHcs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VI8MgCzXHcs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: BONDS ARE GOING CRAZY!!
# Transcript saved and added to zip for: STOCK MARKET IS CRASHING!!
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: THE MARKET IS SQUEEZING!
# Transcript saved and added to zip for: SBF LIVE INTERVIEW WTF
# Could not fetch transcript for https://www.youtube.com/watch?v=TfwVqhoXgSs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TfwVqhoXgSs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: EXCITING TIME FOR STOCKS
# Transcript saved and added to zip for: MONDAY MELTDOW!?
# Transcript saved and added to zip for: STOCK MARKET BLACK FRIDAY (HALF DAY)
# Transcript saved and added to zip for: STOCK MARKET THANKSGIVING!!
# Transcript saved and added to zip for: FED MINUTES LIVE @ 2PM EST
# Transcript saved and added to zip for: TURKEY TUESDAY
# Transcript saved and added to zip for: MONEY MONDAY
# Transcript saved and added to zip for: $2.1 TRILLION Expiration TODAY
# Transcript saved and added to zip for: BULLARD GOES CRAZY!
# Transcript saved and added to zip for: WAR TENSIONS ARE BACK
# Transcript saved and added to zip for: BUFFETT BUYS STOCK
# Transcript saved and added to zip for: MOMENTUM VS. THE FED
# Could not fetch transcript for https://www.youtube.com/watch?v=0BYhYEAEhvI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0BYhYEAEhvI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=_NcT17GAiNY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_NcT17GAiNY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: TURNAROUND TUESDAY
# Transcript saved and added to zip for: MIDTERM MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE
# Could not fetch transcript for https://www.youtube.com/watch?v=fTlfZ48HU0w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fTlfZ48HU0w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: FINAL TRADING DAY OF AUGUST 2022
# Transcript saved and added to zip for: PROFIT OR PANIC!?!?
# Transcript saved and added to zip for: S&P FUTURES DROPPING!
# Could not fetch transcript for https://www.youtube.com/watch?v=E1ZPcSQZZuE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=E1ZPcSQZZuE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: STOCKS + GDP
# Transcript saved and added to zip for: Stocks & Real Estate Pregame
# Transcript saved and added to zip for: ENERGY STOCKS ARE BACK
# Transcript saved and added to zip for: THE DOLLAR WRECKING BALL
# Could not fetch transcript for https://www.youtube.com/watch?v=A8uTEnlwRhg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=A8uTEnlwRhg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THE BIG EXPIRATION
# Transcript saved and added to zip for: FED MOMENTUM
# Transcript saved and added to zip for: RETAIL STOCK EARNINGS!
# Transcript saved and added to zip for: STOCKS ARE GOING CRAZY!!!
# Transcript saved and added to zip for: POWER HOUR MELT UP
# Transcript saved and added to zip for: PUMP IT UP PREMARKET
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# Transcript saved and added to zip for: CPI LOWER, STOCKS HIGHER
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: COIN EARNINGS RUNUP + CPI
# Transcript saved and added to zip for: CPI PREGAME - Stock Market Live
# Could not fetch transcript for https://www.youtube.com/watch?v=2ceowPzhKlw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2ceowPzhKlw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: SOFT LANDING!?
# Transcript saved and added to zip for: TAIWAN TANTRUM (Eases)
# Transcript saved and added to zip for: TAIWAN TENSIONS
# Transcript saved and added to zip for: THE MOST HATED RALLY
# Could not fetch transcript for https://www.youtube.com/watch?v=JV8rxtLcrW8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JV8rxtLcrW8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=TooqpR-QIOY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TooqpR-QIOY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# ...
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: How To Sell Premium Like A Boss – The Poor Man Spread – Option Trading For Beginners
# Could not fetch transcript for https://www.youtube.com/watch?v=BpSRcZWKDCQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BpSRcZWKDCQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=ilpJ1SAbUvk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ilpJ1SAbUvk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=mUdic3vV0Yc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mUdic3vV0Yc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=wEmysW97_Vc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wEmysW97_Vc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=s2lONzA5KWg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=s2lONzA5KWg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=SmFrT-DD85k:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=SmFrT-DD85k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=qcmmtTA2uFU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=qcmmtTA2uFU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=o3fy6f8HtcQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=o3fy6f8HtcQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=HX6xMZyG8mc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HX6xMZyG8mc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Is The Stock Market Going To Crash? – Day Trading Live, Stock Market News & Trading Options!
# Could not fetch transcript for https://www.youtube.com/watch?v=93St_G53gXk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=93St_G53gXk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=VO4Z79gT-Ms:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VO4Z79gT-Ms! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Trading Options! – POWER HOUR Fed Hearing, Brexit, & Banks
# Could not fetch transcript for https://www.youtube.com/watch?v=OeGf7IEEuvs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OeGf7IEEuvs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=9DMsehUikCI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9DMsehUikCI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=22_Qpuh4OuQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=22_Qpuh4OuQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Real Estate Investing For Beginners - Investment Properties & The Housing Marker 2019
# Could not fetch transcript for https://www.youtube.com/watch?v=upVG9TXfKgg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=upVG9TXfKgg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=BzN9O78sOfQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BzN9O78sOfQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=DCLbE59NsoU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DCLbE59NsoU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=p-8AXE35zuY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=p-8AXE35zuY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=tSYERw8HtMc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tSYERw8HtMc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Trading Options! – Robinhood App Account Challenge
# Could not fetch transcript for https://www.youtube.com/watch?v=3tX4soeZrcc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3tX4soeZrcc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Trading Options! – Markets Up On Border Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=offQRnkCLN4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=offQRnkCLN4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Stocks To Trade NOW! Market Volatility & Trade Deal
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Stocks To Trade NOW! Market Volatility & Trade Deal
# Could not fetch transcript for https://www.youtube.com/watch?v=J_pBoaXk_4U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=J_pBoaXk_4U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# 760 out of 1398 videos were successfully transcribed.
# All transcripts are saved in the zip file: Josh_Transcripts.zip
# Download completed. Transcripts saved in the 'Josh_Transcripts.zip'.

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime
import zipfile

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]

            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist
    zip_filename = "Josh_Transcripts.zip"

    # Create a zip file to hold the text files
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        processed_video_ids = set()  # Set to track processed video IDs
        total_transcribed = 0  # Count of successfully transcribed videos
        total_videos = len(video_links)  # Total number of videos

        # Combine the video information into a list of tuples
        videos = list(zip(video_links, video_titles, video_dates))

        # Sort the videos by the publish date (video_dates)
        videos.sort(key=lambda x: datetime.strptime(x[2], "%Y-%m-%dT%H:%M:%SZ"))

        for link, title, date in videos:
            video_id = link.split("v=")[-1]

            # Skip processing if the video has already been processed
            if video_id in processed_video_ids:
                print(f"Skipping duplicate video: {title}")
                continue

            # Add the video ID to the processed set to avoid duplicates
            processed_video_ids.add(video_id)

            sanitized_title = sanitize_filename(title)
            video_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d")
            file_name = f"{sanitized_title}_{video_date}.txt"
            file_path = os.path.join(output_folder, file_name)

            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                with open(file_path, "w", encoding="utf-8") as file:
                    for line in transcript:
                        file.write(f"{line['text']}\n")

                # Add the transcript text file to the zip archive
                zipf.write(file_path, os.path.basename(file_path))
                print(f"Transcript saved and added to zip for: {title}")

                # Clean up by removing the file after adding it to the zip
                os.remove(file_path)
                total_transcribed += 1  # Increment the transcribed count
            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

        # Print out the results
        print(f"\n{total_transcribed} out of {total_videos} videos were successfully transcribed.")
        print(f"All transcripts are saved in the zip file: {zip_filename}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'Josh_Transcripts.zip'.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Could not fetch transcript for https://www.youtube.com/watch?v=XIJCTjau7Us:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XIJCTjau7Us! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=zGmN-HkdimA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zGmN-HkdimA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=R6RZW4TfNGg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=R6RZW4TfNGg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=_BK5IN1OOQ8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_BK5IN1OOQ8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=gdbofkvcsdc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gdbofkvcsdc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=hjfmXaGsnXc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hjfmXaGsnXc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: FUTURES PLUNGE 500 POINTS –Sunday Stock Review Preparing For The Stock Market This Week!
# Could not fetch transcript for https://www.youtube.com/watch?v=-kSZXy0dOZE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-kSZXy0dOZE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=vD0QqyPEV34:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=vD0QqyPEV34! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=cbA6Itd2-Z0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cbA6Itd2-Z0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=B7oLg_VQbzM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=B7oLg_VQbzM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=Xy7OFIL33OA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Xy7OFIL33OA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: STOCKS CRASHING AGAIN!? Trade War  – Day Trading Live, Stock Market News & Stocks To Trade NOW!
# Could not fetch transcript for https://www.youtube.com/watch?v=bk0_AwH9vMk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bk0_AwH9vMk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=OQpmpTQIfXs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OQpmpTQIfXs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=n6Q6s139tj4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n6Q6s139tj4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING TO BE CRAZY TOMORROW! – My Watchlist For Tomorrow – Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=lmhxGGJnKJU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=lmhxGGJnKJU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Sunday Stock Review – Daily Stock Picks – Day Trading Live, Stock Market News & Stocks To Trade NOW!
# Could not fetch transcript for https://www.youtube.com/watch?v=FQ1cdl5CFwI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FQ1cdl5CFwI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=uwxXKbh9eag:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uwxXKbh9eag! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=R0B2zq8D0uw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=R0B2zq8D0uw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=JwReqUNxR5U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JwReqUNxR5U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=-iADHUdGpUE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-iADHUdGpUE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=lyXIAP96-_M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=lyXIAP96-_M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=0hHFXOqubxI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0hHFXOqubxI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=cAcdFAevanE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cAcdFAevanE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Day Trading Live, Stock Market News & Stocks To Trade NOW – MARKET SLIDING DOWN
# Could not fetch transcript for https://www.youtube.com/watch?v=O1vGdJBogOU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=O1vGdJBogOU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=530cG93Deh8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=530cG93Deh8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=NTSRbKSMBjc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NTSRbKSMBjc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: Planning The Riskiest Trade Ever – Day Trading Live, Option Trading, & Stock Market News!
# Could not fetch transcript for https://www.youtube.com/watch?v=5Nte7Ky_7zw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5Nte7Ky_7zw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=b_pT0M2wASQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=b_pT0M2wASQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=
This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MORE TARIFFS ARE COMING – August Stocks – Robinhood Options, Day Trading & Stock News
# Could not fetch transcript for https://www.youtube.com/watch?v=0xVDm_oACtE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0xVDm_oACtE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=iIbnbR_jXrM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iIbnbR_jXrM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: STOCK FUTURES PLUMMET – Live Trading, Robinhood Options, Day Trading & STOCK MARKET NEWS
# Could not fetch transcript for https://www.youtube.com/watch?v=Wc1F8KP1Xjs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Wc1F8KP1Xjs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=BhpCE0MYQO0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BhpCE0MYQO0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=CakiYkLj0AY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CakiYkLj0AY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=QH6hD3Ug-dU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=QH6hD3Ug-dU! This is most likely caused by:
#
# ...
# Could not fetch transcript for https://www.youtube.com/watch?v=UlwwQkPoFEE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UlwwQkPoFEE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: Bank Of Japan Pregame
# Transcript saved and added to zip for: JAPAN RAISES RATES FOR THE FIRST TIME!!!
# Transcript saved and added to zip for: Jerome Powell Live @ 2:30PM EST - FOMC Dot Plot
# Transcript saved and added to zip for: RDDT IPO
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: Data Dump Tuesday
# Transcript saved and added to zip for: Wandering Wednesday
# Transcript saved and added to zip for: LAST TRADING DAY OF THE WEEK
# Transcript saved and added to zip for: THE NEXT QUARTER HAS BEGUN!!!
# Transcript saved and added to zip for: JOLTS Job Openings
# Could not fetch transcript for https://www.youtube.com/watch?v=dmI7Djtv3NY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dmI7Djtv3NY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THETA THURSDAY
# Could not fetch transcript for https://www.youtube.com/watch?v=yH717RplckU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yH717RplckU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=jtKbUVI5a1w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jtKbUVI5a1w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: GOLD IS GOING CRAZY
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST
# Transcript saved and added to zip for: PPI & ECB
# Transcript saved and added to zip for: BANK EARNINGS BEGIN!!! JPM, C, WFC
# Transcript saved and added to zip for: RETAIL SALES, MANUFACTURING & TAX DAY
# Transcript saved and added to zip for: GLOBAL TENSIONS & GLOBAL DATA - Jerome Powell LIVE @ 1:15PM EST
# Transcript saved and added to zip for: INTEREST RATE RECKONING
# Transcript saved and added to zip for: TSM & NFLX EARNINGS
# Transcript saved and added to zip for: WAR TENSIONS ARE BACK
# Transcript saved and added to zip for: $100B MARKET CAP
# Transcript saved and added to zip for: PMI's & EARNINGS SEASON
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: GOOGL & MSFT EARNINGS LIVE - GDP DATA
# Transcript saved and added to zip for: PCE DATA @ 8:30 AM EST
# Transcript saved and added to zip for: ANYTHING BUT BONDS
# Transcript saved and added to zip for: EMPLOYMENT COST INDEX & AMZN EARNINGS
# Transcript saved and added to zip for: FOMC & JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30 AM EST
# Transcript saved and added to zip for: THEY NOT LIKE US MONDAY
# Transcript saved and added to zip for: DISNEY EARNINGS!!! - AAPL EVENT LIVE
# Transcript saved and added to zip for: 10Y AUCTION & EARNINGS
# Transcript saved and added to zip for: THETA THURSDAY STOCK MARKET
# Transcript saved and added to zip for: FACEOFF FRIDAY
# Transcript saved and added to zip for: THE STOCK MARKET IS BACK!! - GME - OPENAI EVENT
# Transcript saved and added to zip for: PPI LIVE @ 8:30AM EST - GME PART 2 - JEROME POWELL LIVE
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: S&P500 ALL TIME HIGHS
# Transcript saved and added to zip for: FREAKY FRIDAY EXPIRATION
# Transcript saved and added to zip for: STOCK MARKET IS INSANE
# Transcript saved and added to zip for: TOO SQUEEZY TUESDAY - MSFT EVENT
# Transcript saved and added to zip for: NVDA EARNINGS LIVE - FOMC MINUTES
# Transcript saved and added to zip for: NVDA STOCK IS GOING IN INSANE
# Transcript saved and added to zip for: SHORT WEEK, NEW HIGHS!
# Transcript saved and added to zip for: Wow it's already Wednesday
# Transcript saved and added to zip for: GDP THURSDAY
# Transcript saved and added to zip for: PCE DATA & FINAL FRIDAY
# Transcript saved and added to zip for: JOBS WEEK - $100M ON GME
# Transcript saved and added to zip for: JOLTS JOB OPENINGS
# Transcript saved and added to zip for: BANK OF CANADA & PRIVATE PAYROLLS
# Could not fetch transcript for https://www.youtube.com/watch?v=uaYX3elpATE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uaYX3elpATE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE
# Transcript saved and added to zip for: STOCK MARKET MONDAY
# Transcript saved and added to zip for: BOND AUCTION & CPI PREGAME
# Transcript saved and added to zip for: JEROME POWELL LIVE
# Transcript saved and added to zip for: PPI & POST POWELL
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: BIG MONEY MONDAY
# Transcript saved and added to zip for: RETAIL SALES
# Transcript saved and added to zip for: GLOBAL DATA
# Transcript saved and added to zip for: S&P PMI
# Transcript saved and added to zip for: MOGUL MONDAY
# Transcript saved and added to zip for: FEDEX EARNINGS
# Transcript saved and added to zip for: MICRON EARNINGS
# Transcript saved and added to zip for: GDP DAY
# Transcript saved and added to zip for: PCE DATA LIVE - POST DEBATE
# Transcript saved and added to zip for: First Trading Day Of July 2024 - RoaringKitty BUYS CHWY
# Transcript saved and added to zip for: JEROME POWELL @ 9:30AM EST - JOLTS Job Openings
# Transcript saved and added to zip for: STOCK MARKET HALF DAY
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: PPI VS. TRADERS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12:30PM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: SMALL CAP ROTATION
# Transcript saved and added to zip for: CHIP STOCK CARNAGE - NFLX EARNINGS LIVE
# Transcript saved and added to zip for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Transcript saved and added to zip for: JOE BIDEN QUITS!!
# Transcript saved and added to zip for: VOLATILITY Is HIDING - TSLA EARNINGS LIVE
# Transcript saved and added to zip for: EARNINGS, FED & END OF THE MONTH TRADING
# Transcript saved and added to zip for: MSFT & AMD EARNINGS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved and added to zip for: INITIAL JOBLESS CLAIMS (People care about it now)
# Transcript saved and added to zip for: THE BIG DATA WEEK
# Transcript saved and added to zip for: PPI DATA
# Transcript saved and added to zip for: Friday After Next Volatility
# Transcript saved and added to zip for: August Volatility - Stock Market LIVE
# Transcript saved and added to zip for: Terrible Tuesday - Stock Market LIVE
# Transcript saved and added to zip for: JOBS REPORT REVISION - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved and added to zip for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CRYPTO IS GOING CRAZY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 3PM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: NVIDIA EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: SCOTT BESSENT IS TREASURER -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Data Dump - GDP, PCE, Personal Income -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Transcript saved and added to zip for: December Stocks - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CRYPTO TO THE....BE RESPONSIBLE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# 614 out of 1398 videos were successfully transcribed.
# All transcripts are saved in the zip file: Josh_Transcripts.zip
# Download completed. Transcripts saved in the 'Josh_Transcripts.zip'.

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os
import re
from datetime import datetime
import zipfile

# Replace with your YouTube Data API v3 key
API_KEY = "AIzaSyBbSiLo7AZbqDd02YZPoPwKB2KgGJE4P60"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def get_channel_video_links_and_dates(channel_id):
    """Fetch all video links, titles, and release dates from a YouTube channel."""
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    video_links = []
    video_titles = []
    video_dates = []

    # Fetch uploads playlist ID for the channel
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    response = request.execute()

    if not response["items"]:
        print("Channel not found!")
        return [], [], []

    uploads_playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    # Fetch videos from the uploads playlist
    next_page_token = None
    while True:
        playlist_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response["items"]:
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]
            video_date = item["snippet"]["publishedAt"]

            video_links.append(f"https://www.youtube.com/watch?v={video_id}")
            video_titles.append(video_title)
            video_dates.append(video_date)

        next_page_token = playlist_response.get("nextPageToken")
        if not next_page_token:
            break

    return video_links, video_titles, video_dates

def sanitize_filename(filename):
    """Sanitize filenames to be compatible with the operating system."""
    return re.sub(r'[\\/*?"<>|]', "_", filename)

def extract_transcripts(video_links, video_titles, video_dates):
    """Extract transcripts for all videos and save each to a separate text file."""
    output_folder = "video_transcripts"
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist
    zip_filename = "Josh_Transcripts.zip"

    # Create a zip file to hold the text files
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        processed_video_ids = set()  # Set to track processed video IDs
        total_transcribed = 0  # Count of successfully transcribed videos
        total_videos = len(video_links)  # Total number of videos

        # Dictionary to track transcriptions per year
        year_transcribed = {}
        year_failed = {}

        for link, title, date in zip(video_links, video_titles, video_dates):
            video_id = link.split("v=")[-1]

            # Skip processing if the video has already been processed
            if video_id in processed_video_ids:
                print(f"Skipping duplicate video: {title}")
                continue

            # Add the video ID to the processed set to avoid duplicates
            processed_video_ids.add(video_id)

            sanitized_title = sanitize_filename(title)
            video_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ")
            video_year = video_date.year
            file_name = f"{sanitized_title}_{video_date.strftime('%Y-%m-%d')}.txt"
            file_path = os.path.join(output_folder, file_name)

            try:
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                with open(file_path, "w", encoding="utf-8") as file:
                    for line in transcript:
                        file.write(f"{line['text']}\n")

                # Add the transcript text file to the zip archive
                zipf.write(file_path, os.path.basename(file_path))
                print(f"Transcript saved and added to zip for: {title}")

                # Clean up by removing the file after adding it to the zip
                os.remove(file_path)
                total_transcribed += 1  # Increment the transcribed count

                # Increment transcribed count for the video year
                if video_year not in year_transcribed:
                    year_transcribed[video_year] = 0
                year_transcribed[video_year] += 1

            except Exception as e:
                print(f"Could not fetch transcript for {link}: {e}")

                # Increment failed count for the video year
                if video_year not in year_failed:
                    year_failed[video_year] = 0
                year_failed[video_year] += 1

        # Print out the results
        print(f"\n{total_transcribed} out of {total_videos} videos were successfully transcribed.")
        print(f"All transcripts are saved in the zip file: {zip_filename}")

        # Display yearly transcribed and failed counts
        print("\nTranscription Statistics by Year:")
        for year in range(2019, 2025):  # Assuming the videos are between 2019 and 2024
            transcribed_count = year_transcribed.get(year, 0)
            failed_count = year_failed.get(year, 0)
            print(f"Year {year}: Transcribed - {transcribed_count}, Not Transcribed - {failed_count}")

if __name__ == "__main__":
    # Replace with the desired YouTube channel ID
    channel_id = "UCsfp0zw1hNxpy_wDig8oExA"  # Replace with the target channel ID

    # Step 1: Get video links, titles, and release dates
    print("Fetching video links, titles, and release dates...")
    video_links, video_titles, video_dates = get_channel_video_links_and_dates(channel_id)

    if video_links:
        print(f"Total videos found: {len(video_links)}")

        # Step 2: Extract transcripts and save to individual files
        print("Extracting transcripts...")
        extract_transcripts(video_links, video_titles, video_dates)

        # Step 3: Inform the user
        print("Download completed. Transcripts saved in the 'Josh_Transcripts.zip'.")
    else:
        print("No videos found or an error occurred.")
# Out:
# Fetching video links, titles, and release dates...
# Total videos found: 1398
# Extracting transcripts...
# Could not fetch transcript for https://www.youtube.com/watch?v=izZ0ZzsJ82A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=izZ0ZzsJ82A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONDAY MANIA - Middle East Conflict - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=u7uOUHbhqXw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=u7uOUHbhqXw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CRYPTO TO THE....BE RESPONSIBLE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=dJ3q7EEKI_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dJ3q7EEKI_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JOLTS JOB OPENINGS - SOUTH KOREA MARTIAL LAW - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: December Stocks - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: 5TH ANNUAL Stock Market Live THANKSGIVING!
# Transcript saved and added to zip for: Data Dump - GDP, PCE, Personal Income -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Tariffs -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Trump Calls For TARIFFS -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: SCOTT BESSENT IS TREASURER -  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: S&P 493-  Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA POST EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVIDIA EARNINGS - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Could not fetch transcript for https://www.youtube.com/watch?v=DhwBunH7pGc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DhwBunH7pGc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: MONEY MONDAY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Retail Sales & Options Expiration - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 3PM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CRYPTO IS GOING CRAZY - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: TRUMP TRADE MANIA - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: McDonald’s E.coli outbreak! STOCK DOWN 10%
# Transcript saved and added to zip for: PRIVATE PAYROLLS (GEOPOLITICS IS COMING BACK) - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: POWELL LIVE @ 9:20AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: PPI PRE-RATE CUT - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: NVDA EARNINGS DAY  - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: JOBS REPORT REVISION - Stock Market LIVE, Live Trading, Stocks To Buy NOW
# Transcript saved and added to zip for: Terrible Tuesday - Stock Market LIVE
# Transcript saved and added to zip for: August Volatility - Stock Market LIVE
# Transcript saved and added to zip for: Friday After Next Volatility
# Transcript saved and added to zip for: PPI DATA
# Transcript saved and added to zip for: THE BIG DATA WEEK
# Transcript saved and added to zip for: INITIAL JOBLESS CLAIMS (People care about it now)
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING CRAZY
# Transcript saved and added to zip for: GLOBAL MARKET SELL OFF - NASDAQ DOWN OVER 5%
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: MSFT & AMD EARNINGS
# Transcript saved and added to zip for: EARNINGS, FED & END OF THE MONTH TRADING
# Transcript saved and added to zip for: VOLATILITY Is HIDING - TSLA EARNINGS LIVE
# Transcript saved and added to zip for: JOE BIDEN QUITS!!
# Transcript saved and added to zip for: MAJOR TECH OUTAGES - POLITICAL VOLATILITY
# Transcript saved and added to zip for: CHIP STOCK CARNAGE - NFLX EARNINGS LIVE
# Transcript saved and added to zip for: SMALL CAP ROTATION
# Could not fetch transcript for https://www.youtube.com/watch?v=_Z-hZ_URBFE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_Z-hZ_URBFE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12:30PM EST
# Transcript saved and added to zip for: PPI VS. TRADERS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: STOCK MARKET HALF DAY
# Transcript saved and added to zip for: JEROME POWELL @ 9:30AM EST - JOLTS Job Openings
# Transcript saved and added to zip for: First Trading Day Of July 2024 - RoaringKitty BUYS CHWY
# Transcript saved and added to zip for: PCE DATA LIVE - POST DEBATE
# Transcript saved and added to zip for: GDP DAY
# Transcript saved and added to zip for: MICRON EARNINGS
# Transcript saved and added to zip for: FEDEX EARNINGS
# Transcript saved and added to zip for: MOGUL MONDAY
# Transcript saved and added to zip for: S&P PMI
# Transcript saved and added to zip for: GLOBAL DATA
# Transcript saved and added to zip for: RETAIL SALES
# Transcript saved and added to zip for: BIG MONEY MONDAY
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: PPI & POST POWELL
# Transcript saved and added to zip for: JEROME POWELL LIVE
# Transcript saved and added to zip for: BOND AUCTION & CPI PREGAME
# Transcript saved and added to zip for: STOCK MARKET MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE
# Could not fetch transcript for https://www.youtube.com/watch?v=uaYX3elpATE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uaYX3elpATE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: BANK OF CANADA & PRIVATE PAYROLLS
# Transcript saved and added to zip for: JOLTS JOB OPENINGS
# Transcript saved and added to zip for: JOBS WEEK - $100M ON GME
# Transcript saved and added to zip for: PCE DATA & FINAL FRIDAY
# Transcript saved and added to zip for: GDP THURSDAY
# Transcript saved and added to zip for: Wow it's already Wednesday
# Transcript saved and added to zip for: SHORT WEEK, NEW HIGHS!
# Transcript saved and added to zip for: NVDA STOCK IS GOING IN INSANE
# Transcript saved and added to zip for: NVDA EARNINGS LIVE - FOMC MINUTES
# Transcript saved and added to zip for: TOO SQUEEZY TUESDAY - MSFT EVENT
# Transcript saved and added to zip for: STOCK MARKET IS INSANE
# Transcript saved and added to zip for: FREAKY FRIDAY EXPIRATION
# Transcript saved and added to zip for: S&P500 ALL TIME HIGHS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: PPI LIVE @ 8:30AM EST - GME PART 2 - JEROME POWELL LIVE
# Transcript saved and added to zip for: THE STOCK MARKET IS BACK!! - GME - OPENAI EVENT
# Transcript saved and added to zip for: FACEOFF FRIDAY
# Transcript saved and added to zip for: THETA THURSDAY STOCK MARKET
# Transcript saved and added to zip for: 10Y AUCTION & EARNINGS
# Transcript saved and added to zip for: DISNEY EARNINGS!!! - AAPL EVENT LIVE
# Transcript saved and added to zip for: THEY NOT LIKE US MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30 AM EST
# Transcript saved and added to zip for: FOMC & JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: EMPLOYMENT COST INDEX & AMZN EARNINGS
# Transcript saved and added to zip for: ANYTHING BUT BONDS
# Transcript saved and added to zip for: PCE DATA @ 8:30 AM EST
# Transcript saved and added to zip for: GOOGL & MSFT EARNINGS LIVE - GDP DATA
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: PMI's & EARNINGS SEASON
# Transcript saved and added to zip for: $100B MARKET CAP
# Transcript saved and added to zip for: WAR TENSIONS ARE BACK
# Transcript saved and added to zip for: TSM & NFLX EARNINGS
# Transcript saved and added to zip for: INTEREST RATE RECKONING
# Transcript saved and added to zip for: GLOBAL TENSIONS & GLOBAL DATA - Jerome Powell LIVE @ 1:15PM EST
# Transcript saved and added to zip for: RETAIL SALES, MANUFACTURING & TAX DAY
# Transcript saved and added to zip for: BANK EARNINGS BEGIN!!! JPM, C, WFC
# Transcript saved and added to zip for: PPI & ECB
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST
# Transcript saved and added to zip for: GOLD IS GOING CRAZY
# Could not fetch transcript for https://www.youtube.com/watch?v=jtKbUVI5a1w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jtKbUVI5a1w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=yH717RplckU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yH717RplckU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THETA THURSDAY
# Could not fetch transcript for https://www.youtube.com/watch?v=dmI7Djtv3NY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dmI7Djtv3NY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JOLTS Job Openings
# Transcript saved and added to zip for: THE NEXT QUARTER HAS BEGUN!!!
# Transcript saved and added to zip for: LAST TRADING DAY OF THE WEEK
# Transcript saved and added to zip for: Wandering Wednesday
# Transcript saved and added to zip for: Data Dump Tuesday
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: RDDT IPO
# Transcript saved and added to zip for: Jerome Powell Live @ 2:30PM EST - FOMC Dot Plot
# Transcript saved and added to zip for: JAPAN RAISES RATES FOR THE FIRST TIME!!!
# Transcript saved and added to zip for: Bank Of Japan Pregame
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Could not fetch transcript for https://www.youtube.com/watch?v=UlwwQkPoFEE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UlwwQkPoFEE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Could not fetch transcript for https://www.youtube.com/watch?v=MnDj0KtB-Vc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=MnDj0KtB-Vc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: Daylight LONGTERMS
# Could not fetch transcript for https://www.youtube.com/watch?v=Gzn2T8P-gII:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Gzn2T8P-gII! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: JEROME POWELL LIVE DAY 2
# Transcript saved and added to zip for: JOLTS JOB OPENINGS & JEROME POWELL LIVE
# Transcript saved and added to zip for: ISM SERVICES & CHIP STOCK MANIA
# Transcript saved and added to zip for: BEWARE THE IDES OF MARCH
# Transcript saved and added to zip for: THE FIRST TRADING DAY OF MARCH!!
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP @ 8:30 AM EST
# Transcript saved and added to zip for: Durable Goods & Consumer Confidence
# Transcript saved and added to zip for: MOMENTUM MONDAY
# Transcript saved and added to zip for: MARKET SENTIMENT FRIDAY
# Could not fetch transcript for https://www.youtube.com/watch?v=NeUsNAcgF7Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NeUsNAcgF7Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: NVDA EARNINGS LIVE AH
# Transcript saved and added to zip for: WMT & HD EARNINGS
# Could not fetch transcript for https://www.youtube.com/watch?v=AhgU7Pku_4E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AhgU7Pku_4E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: The Battle of 5000 SPX
# Could not fetch transcript for https://www.youtube.com/watch?v=fbl-_xtyC9g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fbl-_xtyC9g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED SPEAKERS & CPI WEEK
# Transcript saved and added to zip for: CPI REVISIONS @ 8:30AM EST
# Transcript saved and added to zip for: THE DAY BEFORE THE REVISIONS
# Transcript saved and added to zip for: 10YR BOND AUCTION & BANK STOCK BLUNDER
# Transcript saved and added to zip for: Fed Speakers day 2
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: T'was The Day After Powell - AAPL, AMZN & META EARNINGS LIVE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: JOLTS JOBS & MSFT EARNINGS LIVE
# Transcript saved and added to zip for: STOCK EARNINGS EVERYWHERE!!!!
# Transcript saved and added to zip for: INTC EARNINGS LIVE
# Transcript saved and added to zip for: TSLA EARNINGS LIVE AH
# Transcript saved and added to zip for: TOP TICK TUESDAY
# Transcript saved and added to zip for: Rate Cuts vs. Earnings
# Transcript saved and added to zip for: THE OPTION EXPIRATION SCAM
# Transcript saved and added to zip for: THE BOSTIC BOUNCE
# Transcript saved and added to zip for: RETAIL SALES @ 8:30AM EST
# Transcript saved and added to zip for: STOCK MARKET WEEK 3 - BANK EARINGS & DATA
# Transcript saved and added to zip for: PPI @ 8:30AM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: 10YR BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Stock Market MOMENTUM
# Transcript saved and added to zip for: BA STOCK FIASCO
# Transcript saved and added to zip for: PMI SERVICES
# Transcript saved and added to zip for: FED MINUTES & JOLTS JOB REPORT
# Transcript saved and added to zip for: THE OPENING TRADE OF THE YEAR
# Transcript saved and added to zip for: NIIIIIIIIIIKEEEEESSSSSS - Stock Market IS GOING CRAZY
# Transcript saved and added to zip for: GDP DATA & MARKET SPOOKED
# Transcript saved and added to zip for: BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Bank Of Powell
# Transcript saved and added to zip for: CYCLICAL MONDAYS
# Transcript saved and added to zip for: PMI DATA & STOCK MARKET HIGHS!!!!
# Transcript saved and added to zip for: ECB, Bank Of England & RETAIL SALES - STOCK MARKET AT HIGHS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE BIGGEST WEEK FOR STOCKS
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: THETA THURSDAY
# Transcript saved and added to zip for: ADP PRIVATE PAYROLLS
# Transcript saved and added to zip for: JOLTS JOBS DATA & ISM SERVICES
# Transcript saved and added to zip for: MONDAY MELT UP
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 11AM EST
# Transcript saved and added to zip for: REAL Tesla Cyber Truck Event LIVE
# Transcript saved and added to zip for: GDP DATA
# Transcript saved and added to zip for: FED SPEAKERS & BOND AUCTION
# Transcript saved and added to zip for: MONDAY MARKET MOVERS
# Transcript saved and added to zip for: BLACK FRIDAY STOCK MARKET
# Transcript saved and added to zip for: 4th Annual Stock Market THANKSGIVING
# Transcript saved and added to zip for: Durable Goods & Consumer Sentiment (LOW VOLUME TRADING)
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: 20 YEAR BOND AUCTION @ 1PM EST
# Transcript saved and added to zip for: Fakeout Friday
# Transcript saved and added to zip for: FED SPEAKERS VS. MARKET RALLY
# Transcript saved and added to zip for: PPI REPORT & RETAIL SALES
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: The Market IS WILD
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2PM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE PREMARKET
# Transcript saved and added to zip for: The FIRST Bond Auction Of The Week
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AAPL EARNINGS LIVE (The stock market is still reacting to Powell though)
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved and added to zip for: Relief or Reverse
# Transcript saved and added to zip for: MOODY MONDAY
# Transcript saved and added to zip for: FEARFUL FRIDAY
# Transcript saved and added to zip for: AMZN EARNINGS + MARKET CARNAGE
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: Rates Vs. War
# Transcript saved and added to zip for: FREAK OUT FRIDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12PM EST
# Transcript saved and added to zip for: TSLA & NFLX EARNINGS + Global Conflict
# Transcript saved and added to zip for: GS, BAC, JNJ, LMT EARNINGS
# Transcript saved and added to zip for: EARNINGS SEASON BEGINS - Stock Market Today
# Transcript saved and added to zip for: CONSUMER SENTIMENT + BOND BLOWOUT - Stock Market Today
# Transcript saved and added to zip for: CPI LIVE @8:30AM EST - Stock Market Today
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST - Stock Market Today
# Transcript saved and added to zip for: GLOBAL TENSIONS
# Transcript saved and added to zip for: THE WEEK OF THE CPI
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED SPEAKERS
# Transcript saved and added to zip for: ISM SERVICES @ 10AM EST
# Transcript saved and added to zip for: JOLTS JOB OPENINGS @ 10AM EST
# Transcript saved and added to zip for: JEROME POWELL ROUNDTABLE  LIVE @ 11AM EST
# Transcript saved and added to zip for: PCE & Consumer Sentiment
# Transcript saved and added to zip for: GDP Vs. OIL
# Transcript saved and added to zip for: WAKE UP WEDNESDAY
# Transcript saved and added to zip for: BOND BLOWOUT
# Transcript saved and added to zip for: Oil & Interest Rates
# Transcript saved and added to zip for: THE DOLLAR VS. THE STOCK MARKET
# Transcript saved and added to zip for: POST FED DATA DUMP
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: MONEY - INSTACART IPO LIVE
# Transcript saved and added to zip for: POST EXPIRATION SETUP
# Transcript saved and added to zip for: UAW GOES ON STRIKE
# Transcript saved and added to zip for: ARM IPO LIVE!
# Transcript saved and added to zip for: AUGUST CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: EUROPE IS MOVING MARKETS - AAPL NEW IPHONE
# Transcript saved and added to zip for: TESTING SEE YOU IN THE MORNING
# Transcript saved and added to zip for: MACRO MONDAY
# Transcript saved and added to zip for: The Stock Market HATES September
# Transcript saved and added to zip for: STOCK MARKET LIVE - THETA THURSDAY
# Transcript saved and added to zip for: ISM SERVICES
# Transcript saved and added to zip for: SEPTEMBER SEASONALITY
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: BULLS VS. BONDS
# Transcript saved and added to zip for: JOLTS JOB OPENINGS
# Transcript saved and added to zip for: The Day After POWELL
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST - Jackson Hole Symposium
# Transcript saved and added to zip for: AI STOCK BUBBLE
# Transcript saved and added to zip for: NVDA EARNINGS LIVE
# Transcript saved and added to zip for: Curve Steepener - LIVE TRADING
# Transcript saved and added to zip for: THE BIG OPTION EXPIRATION - LIVE TRADING
# Transcript saved and added to zip for: POWELL & NVDA - LIVE TRADING
# Transcript saved and added to zip for: GLOBAL BOND BLOWOUT - LIVE TRADING
# Transcript saved and added to zip for: FED MINUTES - LIVE TRADING
# Transcript saved and added to zip for: RETAIL SALES - LIVE TRADING
# Transcript saved and added to zip for: CHINA CONTAGION  - LIVE TRADING
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - LIVE TRADING
# Transcript saved and added to zip for: WILD WEDNESDAY - LIVE TRADING
# Transcript saved and added to zip for: TIMID TUESDAY - LIVE TRADING
# Transcript saved and added to zip for: MOODY MONDAY - LIVE TRADING
# Transcript saved and added to zip for: AMZN & AAPL EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: FITCH DOWNGRADES THE USA - LIVE TRADING
# Transcript saved and added to zip for: AMD EARNINGS AFTER HOURS - LIVE TRADING
# Transcript saved and added to zip for: LAST DAY OF JULY - LIVE TRADING
# Transcript saved and added to zip for: ECB & EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - LIVE TRADING
# Transcript saved and added to zip for: GOOGL & MSFT EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: MONDAY MANIA - LIVE TRADING
# Transcript saved and added to zip for: FOLLOW THROUGH FRIDAY - LIVE TRADING
# Transcript saved and added to zip for: TSM & JNJ  EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: NFLX & TSLA EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: BANK EARNINGS EVERYWHERE - LIVE TRADING
# Transcript saved and added to zip for: EMPIRE MANUFACTURING DATA - LIVE TRADING
# Transcript saved and added to zip for: BANK STOCK EARNINGS - LIVE TRADING
# Transcript saved and added to zip for: Producer Price Inflation & EARNINGS  - LIVE TRADING
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST - LIVE TRADING
# Transcript saved and added to zip for: EARNINGS SEASON PREGAME - LIVE TRADING
# Transcript saved and added to zip for: FED SPEAKER MONDAY - LIVE TRADING
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST  - LIVE TRADING
# Transcript saved and added to zip for: ISM SERVICES, YELLEN IN CHINA, META THREADS  - LIVE TRADING
# Transcript saved and added to zip for: HALF DAY FREEDOM DAY
# Transcript saved and added to zip for: FINAL TRADING DAY OF THE MONTH
# Transcript saved and added to zip for: REBALANCE THURSDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 9:30AM EST
# Transcript saved and added to zip for: TUESDAY ECONOMIC DATA DUMP
# Transcript saved and added to zip for: Time to Hedge?
# Transcript saved and added to zip for: FROTHY FRIDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE DAY 2
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: FED SPEAKERS ALL WEEK
# Transcript saved and added to zip for: FED BULLARD & FED WALLER
# Transcript saved and added to zip for: THEY REALLY PAUSED!!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE BIGGEST TRADING WEEK
# Transcript saved and added to zip for: FORGET IT FRIDAY
# Transcript saved and added to zip for: TOP TICK THURSDAY
# Transcript saved and added to zip for: WONDERING WEDNESDAY
# Transcript saved and added to zip for: TURBULENT TUESDAY
# Transcript saved and added to zip for: PMI & ISM DATA
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: DEBT LIMIT WINS HOUSE PASSAGE
# Transcript saved and added to zip for: JOB OPENINGS & FED SPEAKERS
# Transcript saved and added to zip for: DEBT CEILING DEAL!!
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST - DEBT CEILING SHOWDOWN
# Transcript saved and added to zip for: UNITED STATES ON CREDIT WATCH
# Transcript saved and added to zip for: Fed Minutes @ 2PM EST
# Transcript saved and added to zip for: Jerome Powell Live @ New Democratic Coalition Lunch
# Transcript saved and added to zip for: FED SPEAKERS & Debt Ceiling
# Transcript saved and added to zip for: POWELL LIVE @ 11AM EST
# Transcript saved and added to zip for: BABA & WMT EARNINGS
# Transcript saved and added to zip for: Wait For Powell Wednesday
# Transcript saved and added to zip for: TUESDAY DATA DUMP
# Transcript saved and added to zip for: FED SPEAKER DAY
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# Transcript saved and added to zip for: PPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: DEBT CEILING DEBATE
# Transcript saved and added to zip for: MORE NEWS MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AAPL EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC LIVE
# Transcript saved and added to zip for: AMD EARNINGS LIVE AH
# Transcript saved and added to zip for: FIRST REPUBLIC BANK IS DONE
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: AMZN EARNINGS LIVE
# Transcript saved and added to zip for: META EARNINGS LIVE
# Transcript saved and added to zip for: MSFT & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: FRC EARNINGS AH
# Transcript saved and added to zip for: STOCK MARKET SENTIMENT SOURS
# Transcript saved and added to zip for: TSM, AXP & REGIONAL BANK EARNINGS
# Transcript saved and added to zip for: TESLA CONFERENCE CALL LIVE
# Transcript saved and added to zip for: TSLA EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: NFLX Q1 EARNINGS LIVE @ 4PM EST
# Transcript saved and added to zip for: REGIONAL BANK EARNINGS
# Transcript saved and added to zip for: AIRLINE EARNINGS
# Transcript saved and added to zip for: PPI & AIRLINE EARNINGS!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: CPI PREVIEW
# Transcript saved and added to zip for: THE STOCK MARKET IS GOING TO GO CRAZY THIS WEEK!!
# Transcript saved and added to zip for: THETA THURSDAY!!
# Transcript saved and added to zip for: WHATS REALLY GOING ON WEDNESDAY!?
# Transcript saved and added to zip for: OIL MARKET MALARKEY
# Transcript saved and added to zip for: OPEC SURPRISE CUT
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: NASDAQ BULL MARKET
# Transcript saved and added to zip for: MARKET GAP UP!!
# Transcript saved and added to zip for: FED, FDIC & TREASURY HOUSE TESTIMONY LIVE
# Transcript saved and added to zip for: MONDAY MELTUP?
# Transcript saved and added to zip for: FAKE OUT FRIDAY
# Transcript saved and added to zip for: POST POWELL CARNAGE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: Banks Vs. Powell
# Transcript saved and added to zip for: CREDIT SUISSE BUYOUT
# Transcript saved and added to zip for: FRIDAY BANK WATCH
# Transcript saved and added to zip for: FRC IS BEING RESCUED
# Transcript saved and added to zip for: EURO BANK RUN
# Transcript saved and added to zip for: EURO BANKING CRISIS PT.2
# Transcript saved and added to zip for: EURO BANK CRISIS
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: FED INTERVENTION - SBV & SBNY FAILURE
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE @ 8:30AM EST
# Transcript saved and added to zip for: TOP TICK THURSDAY
# Transcript saved and added to zip for: JEROME POWELL LIVE  @ 10AM EST - HOUSE FINANCIAL SERVICES
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 10AM EST
# Transcript saved and added to zip for: MONDAY MELT
# Transcript saved and added to zip for: FRIDAY FINALE
# Transcript saved and added to zip for: THE STOCK MARKET IS INSANE
# Transcript saved and added to zip for: WELCOME TO MARCH!!!
# Transcript saved and added to zip for: [Insert witty title] TUESDAY
# Transcript saved and added to zip for: MAKE IT OR BREAK IT MONDAY
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP DATA LIVE!
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: TURN-AROUND TUESDAY
# Transcript saved and added to zip for: FRIDAY FIASCO!!!
# Transcript saved and added to zip for: PPI DATA @ 8:30AM EST
# Transcript saved and added to zip for: RETAIL SALES
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: THE CPI SETUP
# Transcript saved and added to zip for: CONSUMER SENTIMENT
# Transcript saved and added to zip for: JOBLESS CLAIMS & PYPL EARNINGS
# Transcript saved and added to zip for: DIS EARNINGS LIVE!
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 12:40PM EST
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: NON FARM PAYROLLS!!!
# Transcript saved and added to zip for: AAPL, AMZN & GOOGL EARNINGS LIVE
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST - FOMC
# Transcript saved and added to zip for: SNAP & AMD EARNINGS LIVE
# Transcript saved and added to zip for: MONDAY MANIA
# Transcript saved and added to zip for: PCE LIVE @ 8:30AM EST
# Transcript saved and added to zip for: GDP & JOBLESS CLAIMS LIVE!
# Transcript saved and added to zip for: TSLA EARNINGS LIVE!!
# Transcript saved and added to zip for: MSFT EARNINGS LIVE!!
# Transcript saved and added to zip for: EARNINGS SEASON
# Transcript saved and added to zip for: NFLX EARNINGS LIVE!
# Transcript saved and added to zip for: PPI @ 5:30AM EST
# Transcript saved and added to zip for: THE GENERATIONAL RALLY
# Transcript saved and added to zip for: BANK EARNINGS BEGIN!!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: INFLATION BREAKDOWN
# Transcript saved and added to zip for: JEROME POWELL LIVE!
# Transcript saved and added to zip for: EARNINGS, POWELL & CPI!
# Transcript saved and added to zip for: 🚨NON FARM PAYROLLS @ 8:30AM EST🚨
# Transcript saved and added to zip for: JOBLESS CLAIMS & PMI
# Transcript saved and added to zip for: FED MINUTES @ 2PM EST
# Transcript saved and added to zip for: 1st Trading Day of The YEAR
# Transcript saved and added to zip for: THE FINAL TRADING DAY OF THE YEAR 2022
# Transcript saved and added to zip for: TIPPING POINT THURSDAY
# Transcript saved and added to zip for: FINAL WEDNESDAY of 2022
# Transcript saved and added to zip for: THE FINAL TUESDAY OF THE YEAR!!
# Transcript saved and added to zip for: PCE @ 8:30AM EST
# Transcript saved and added to zip for: JOBLESS CLAIMS @ 8:30AM EST
# Transcript saved and added to zip for: BOJ DAY 2
# Transcript saved and added to zip for: BANK OF JAPAN SHOCKS THE WORLD
# Transcript saved and added to zip for: HOMEBUILDER DATA @ 10AM EST
# Transcript saved and added to zip for: $3.7 TRILLION EXPIRATION
# Transcript saved and added to zip for: JOBLESS CLAIMS
# Transcript saved and added to zip for: JEROME POWELL LIVE @ 2:30PM EST
# Transcript saved and added to zip for: $20K in 10 days. Tomorrow will be crazier…
# Transcript saved and added to zip for: CPI LIVE @ 8:30 AM EST
# Transcript saved and added to zip for: MARKET MELT
# Transcript saved and added to zip for: PRODUCER PRICE INDEX & CONSUMER SENTIMENT!
# Transcript saved and added to zip for: JOBLESS CLAIMS @ 8:30 AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=VI8MgCzXHcs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VI8MgCzXHcs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: BONDS ARE GOING CRAZY!!
# Transcript saved and added to zip for: STOCK MARKET IS CRASHING!!
# Transcript saved and added to zip for: NON FARM PAYROLLS @ 8:30AM EST
# Transcript saved and added to zip for: THE MARKET IS SQUEEZING!
# Transcript saved and added to zip for: SBF LIVE INTERVIEW WTF
# Could not fetch transcript for https://www.youtube.com/watch?v=TfwVqhoXgSs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TfwVqhoXgSs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: EXCITING TIME FOR STOCKS
# Transcript saved and added to zip for: MONDAY MELTDOW!?
# Transcript saved and added to zip for: STOCK MARKET BLACK FRIDAY (HALF DAY)
# Transcript saved and added to zip for: STOCK MARKET THANKSGIVING!!
# Transcript saved and added to zip for: FED MINUTES LIVE @ 2PM EST
# Transcript saved and added to zip for: TURKEY TUESDAY
# Transcript saved and added to zip for: MONEY MONDAY
# Transcript saved and added to zip for: $2.1 TRILLION Expiration TODAY
# Transcript saved and added to zip for: BULLARD GOES CRAZY!
# Transcript saved and added to zip for: WAR TENSIONS ARE BACK
# Transcript saved and added to zip for: BUFFETT BUYS STOCK
# Transcript saved and added to zip for: MOMENTUM VS. THE FED
# Could not fetch transcript for https://www.youtube.com/watch?v=0BYhYEAEhvI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0BYhYEAEhvI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Could not fetch transcript for https://www.youtube.com/watch?v=_NcT17GAiNY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_NcT17GAiNY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: TURNAROUND TUESDAY
# Transcript saved and added to zip for: MIDTERM MONDAY
# Transcript saved and added to zip for: NON FARM PAYROLLS LIVE
# Could not fetch transcript for https://www.youtube.com/watch?v=fTlfZ48HU0w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fTlfZ48HU0w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: FINAL TRADING DAY OF AUGUST 2022
# Transcript saved and added to zip for: PROFIT OR PANIC!?!?
# Transcript saved and added to zip for: S&P FUTURES DROPPING!
# Could not fetch transcript for https://www.youtube.com/watch?v=E1ZPcSQZZuE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=E1ZPcSQZZuE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: STOCKS + GDP
# Transcript saved and added to zip for: Stocks & Real Estate Pregame
# Transcript saved and added to zip for: ENERGY STOCKS ARE BACK
# Transcript saved and added to zip for: THE DOLLAR WRECKING BALL
# Could not fetch transcript for https://www.youtube.com/watch?v=A8uTEnlwRhg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=A8uTEnlwRhg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Transcript saved and added to zip for: THE BIG EXPIRATION
# Transcript saved and added to zip for: FED MOMENTUM
# Transcript saved and added to zip for: RETAIL STOCK EARNINGS!
# Transcript saved and added to zip for: STOCKS ARE GOING CRAZY!!!
# Transcript saved and added to zip for: POWER HOUR MELT UP
# Transcript saved and added to zip for: PUMP IT UP PREMARKET
# Transcript saved and added to zip for: CONSUMER SENTIMENT @ 10AM EST
# Transcript saved and added to zip for: CPI LOWER, STOCKS HIGHER
# Transcript saved and added to zip for: CPI LIVE @ 8:30AM EST
# Transcript saved and added to zip for: COIN EARNINGS RUNUP + CPI
# Transcript saved and added to zip for: CPI PREGAME - Stock Market Live
# Could not fetch transcript for https://www.youtube.com/watch?v=2ceowPzhKlw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=